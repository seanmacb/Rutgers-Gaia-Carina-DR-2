# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing all the files to dataframes

# %%
file="1529094462290O-result.csv" #The Gaia Data file

knownmemberlist="asu.csv" #The known member list data file

martinfile="martindata.csv" #The martin data

norrisdata="NorrisData.csv" #The Norris data

#SELECT TOP 500 ra,ra_error,dec,dec_error,parallax,parallax_error,pmra,pmra_error,pmdec,pmdec_error,phot_g_mean_mag,phot_bp_mean_mag,phot_rp_mean_mag, bp_rp FROM gaiadr2.gaia_source  WHERE CONTAINS(POINT('ICRS',gaiadr2.gaia_source.ra,gaiadr2.gaia_source.dec),CIRCLE('ICRS',210.025,14.5,0.21333333333333335))=1 AND  (phot_bp_mean_mag>=16 AND phot_g_mean_mag>=16 AND phot_rp_mean_mag>=16 AND phot_g_mean_mag<=20)

# %%
#Reading in the two files to dataframes

df=pandas.read_csv(file) #This is the gaia data
dfmember=pandas.read_csv(knownmemberlist) #This is the Koposov data
dfmartin=pandas.read_csv(martinfile)
dfnorris=pandas.read_csv(norrisdata)

dfra=df["ra"].values.tolist() #putting the data from the data frame of position into lists
dfdec=df["dec"].values.tolist() #THIS CHUNK IS GAIA DATA
dfra_error=df["ra_error"].values.tolist()
dfdec_error=df["dec_error"].values.tolist()
dfrapm=df["pmra"].values.tolist()
dfdecpm=df["pmdec"].values.tolist()
dfrapm_error=df["pmra_error"].values.tolist()
dfdecpm_error=df["pmdec_error"].values.tolist()

dfmemberra=dfmember["RA"].values.tolist() #Taking member ra and dec from dataframe to list
dfmemberdec=dfmember["DEC"].values.tolist() #THIS CHUNK IS KOPOSOV DATA
dfmemberbestfitflag=dfmember["Mm"].values.tolist()
dfmemberrvall=dfmember["RV"].values.tolist()
dfmemberrvall_error=dfmember["e_RV"].values.tolist()
dfmembergmag=dfmember["gmag"].values.tolist()

martinra=dfmartin["RA"].values.tolist() #THIS CHUNK IS MARTIN DATA
martindec=dfmartin["DEC"].values.tolist()
martinmember=dfmartin["Mm"].values.tolist()

norrisra=dfnorris["RA"].values.tolist() #This chunk is Norris data
norrisdec=dfnorris["DEC"].values.tolist()
norrismember=dfnorris["Mm"].values.tolist()
norrisrv=dfnorris["RV"].values.tolist()

# %%
for i in range(len(dfmemberrvall)): #looping through to evaluate RV values to make it easier later
    if dfmemberrvall[i]!="X":
        dfmemberrvall[i]=eval(dfmemberrvall[i])
        dfmemberrvall_error[i]=eval(dfmemberrvall_error[i])

# %%
dfmemberbestra=[]
dfmemberbestdec=[]
dfmembernotbestra=[]
dfmembernotbestdec=[]

for i in range(len(dfmemberbestfitflag)): #finding the ra's and decs for which the points are classified as the best fit, which are not
    if dfmemberbestfitflag[i]=="B":
        dfmemberbestra.append(i)
        dfmemberbestdec.append(i)
    else:
        dfmembernotbestra.append(i)
        dfmembernotbestdec.append(i)

# %%
crosscheckpmra=[] #Creating lists to be filled with pm coordinates that were of "Best fit" only sorted by distance
crosscheckpmdec=[]
crosscheckpmra_error=[]
crosscheckpmdec_error=[]

for item in range(len(dfmemberbestra)): #The double for loop for the best fit graph appending stuff by only distance
    dist=10**10
    
    for items in range(len(dfra)):
        newdist=np.sqrt((dfra[items]-dfmemberra[dfmemberbestra[item]])**2+(dfdec[items]-dfmemberdec[dfmemberbestdec[item]])**2)
        if newdist<=dist:
            dist=newdist
            closestpmra=dfrapm[items]
            closestpmdec=dfdecpm[items]
            closestpmra_error=dfrapm_error[items]
            closestpmdec_error=dfdecpm_error[items]
        else:
            dist=dist
    
    if dist<=0.0056: #Checking if the distance is within 2 arc seconds
        crosscheckpmra.append(closestpmra) 
        crosscheckpmdec.append(closestpmdec)
        crosscheckpmra_error.append(closestpmra_error)
        crosscheckpmdec_error.append(closestpmdec_error)

    closestpmra=0
    closestpmdec=0
    closestpmra_error=0
    closestpmdec_error=0

# %%
badpmra=[] #Creating lists to be filled with pm coordinates that were of "Not best fit" only sorted by distance
badpmdec=[]
badpmra_error=[]
badpmdec_error=[]


for item in range(len(dfmembernotbestra)): #The double for loop for the not best fit flag coordinates
    dist=10**10
    
    for items in range(len(dfra)):
        newdist=np.sqrt((dfra[items]-dfmemberra[dfmembernotbestra[item]])**2+(dfdec[items]-dfmemberdec[dfmembernotbestdec[item]])**2)
        if newdist<=dist:
            dist=newdist
            closestpmra=dfrapm[items]
            closestpmdec=dfdecpm[items]
            closestpmra_error=dfrapm_error[items]
            closestpmdec_error=dfdecpm_error[items]
        else:
            dist=dist
    
    badpmra.append(closestpmra)
    badpmdec.append(closestpmdec)
    badpmra_error.append(closestpmra_error)
    badpmdec_error.append(closestpmdec_error)
    closestpmra=0
    closestpmdec=0
    closestpmra_error=0
    closestpmdec_error=0

# %%
#Filtering by RV's        

koposovmemberrvbestloc=[]
koposovmemberrvworstloc=[]

#looping through to limit the locations to Radial velocities between 95-110 km/s, can change below if you want

for i in range (len(dfmemberrvall)): 
    if dfmemberrvall[i]!="X":
        if dfmemberrvall[i]>=85 and dfmemberrvall[i]<=120:
            koposovmemberrvbestloc.append(i)
        else:
            koposovmemberrvworstloc.append(i)

# %%
print("Koposov In RV:", len(koposovmemberrvbestloc))
print("Koposov Out of RV:", len(koposovmemberrvworstloc))
print()
# Out:
# Koposov In RV: 74
# Koposov Out of RV: 38

# %%
koposovrafit_byrv=[] #member RA's, Dec's, and Errors in the Gaussian to be filled in the next loop
koposovdecfit_byrv=[]

for i in range (len(koposovmemberrvbestloc)): #Appending based on the locations taken above 
    koposovrafit_byrv.append(dfmemberra[koposovmemberrvbestloc[i]])
    koposovdecfit_byrv.append(dfmemberdec[koposovmemberrvbestloc[i]])

# %%
koposovranofit_byrv=[] #appending the member stars ra's and dec's that are outside the velocity range
koposovdecnofit_byrv=[]

for i in range (len(koposovmemberrvworstloc)):
    koposovranofit_byrv.append(dfmemberra[koposovmemberrvworstloc[i]])
    koposovdecnofit_byrv.append(dfmemberdec[koposovmemberrvworstloc[i]])

# %%
#Finding the closest RA and Dec by filtering through only with the RV locations
kopra_fit_byrv_inrange=[]
kopdec_fit_byrv_inrange=[]

koppmra_fromgaia_byrv_inrange=[] #PROPER MOTIONS for fits by rv
koppmdec_fromgaia_byrv_inrange=[]
koppmra_error_fromgaia_byrv_inrange=[]
koppmdec_error_fromgaia_byrv_inrange=[]

kopra_nofit_byrv_inrange=[]
kopdec_nofit_byrv_inrange=[]

countgood=0
countbad=0

for kop in range( len (koposovrafit_byrv) ):
    dist=10**5
    kopclosera=koposovrafit_byrv[kop]
    kopclosedec=koposovdecfit_byrv[kop]
    for gai in range ( len (dfra) ):
        newdist=np.sqrt((koposovdecfit_byrv[kop]-dfdec[gai])**2+(koposovrafit_byrv[kop]-dfra[gai])**2)
        if newdist<=dist:
            dist=newdist
            kopclosestpmra=dfrapm[gai]
            kopclosestpmdec=dfdecpm[gai]
            kopclosestpmra_error=dfrapm_error[gai]
            kopclosestpmdec_error=dfdecpm_error[gai]

    if dist<=1/1800:
        countgood+=1
        kopra_fit_byrv_inrange.append(kopclosera)
        kopdec_fit_byrv_inrange.append(kopclosedec)
        koppmra_fromgaia_byrv_inrange.append(kopclosestpmra)
        koppmdec_fromgaia_byrv_inrange.append(kopclosestpmdec)
        koppmra_error_fromgaia_byrv_inrange.append(kopclosestpmra_error)
        koppmdec_error_fromgaia_byrv_inrange.append(kopclosestpmdec_error)
        print("Match - Koposov Star in RV range index value:",kop)
        print("Distance:",dist*3600,"arcseconds")
        print("G value:",dfmembergmag[koposovmemberrvbestloc[kop]])
        print("Radial Velocity:",dfmemberrvall[koposovmemberrvbestloc[kop]])
        print()
    
    else:
        kopra_nofit_byrv_inrange.append(kopclosera)
        kopdec_nofit_byrv_inrange.append(kopclosedec)
        print("No Match - Koposov star in RV range index value:",kop)
        print("Distance:",dist*3600,"arcseconds")
        print("G value:",dfmembergmag[koposovmemberrvbestloc[kop]])
        print("Radial Velocity:",dfmemberrvall[koposovmemberrvbestloc[kop]])
        countbad+=1
        print()

print("Number of distance matches in RV range:",countgood)
print("Number of non distance matches in RV range that did not match:",countbad)
print()
# Out:
# No Match - Koposov star in RV range index value: 0
# Distance: 8.936462397110068 arcseconds
# G value: 21.9
# Radial Velocity: 115.4
#
# No Match - Koposov star in RV range index value: 1
# Distance: 27.940507782001063 arcseconds
# G value: 21.6
# Radial Velocity: 103.23
#
# Match - Koposov Star in RV range index value: 2
# Distance: 0.05895579940620972 arcseconds
# G value: 20.4
# Radial Velocity: 101.91
#
# Match - Koposov Star in RV range index value: 3
# Distance: 0.14218521732317912 arcseconds
# G value: 19.6
# Radial Velocity: 90.34
#
# Match - Koposov Star in RV range index value: 4
# Distance: 0.08521152451569398 arcseconds
# G value: 20.7
# Radial Velocity: 99.81
#
# Match - Koposov Star in RV range index value: 5
# Distance: 0.29906167360464914 arcseconds
# G value: 20.4
# Radial Velocity: 97.93
#
# Match - Koposov Star in RV range index value: 6
# Distance: 0.05765031614816387 arcseconds
# G value: 20.8
# Radial Velocity: 103.07
#
# Match - Koposov Star in RV range index value: 7
# Distance: 0.18259464692087946 arcseconds
# G value: 21.2
# Radial Velocity: 102.84
#
# No Match - Koposov star in RV range index value: 8
# Distance: 17.81887062619316 arcseconds
# G value: 22.2
# Radial Velocity: 100.09
#
# No Match - Koposov star in RV range index value: 9
# Distance: 29.228535945399955 arcseconds
# G value: 21.7
# Radial Velocity: 91.91
#
# Match - Koposov Star in RV range index value: 10
# Distance: 0.20403896273585959 arcseconds
# G value: 20.4
# Radial Velocity: 98.12
#
# No Match - Koposov star in RV range index value: 11
# Distance: 30.50065712279826 arcseconds
# G value: 21.5
# Radial Velocity: 100.99
#
# Match - Koposov Star in RV range index value: 12
# Distance: 0.1901179558859316 arcseconds
# G value: 20.9
# Radial Velocity: 103.2
#
# Match - Koposov Star in RV range index value: 13
# Distance: 0.11936544695999086 arcseconds
# G value: 19.7
# Radial Velocity: 106.17
#
# Match - Koposov Star in RV range index value: 14
# Distance: 0.19014389361856873 arcseconds
# G value: 20.3
# Radial Velocity: 111.75
#
# Match - Koposov Star in RV range index value: 15
# Distance: 0.02183416254509532 arcseconds
# G value: 20.3
# Radial Velocity: 101.74
#
# No Match - Koposov star in RV range index value: 16
# Distance: 40.98190824590499 arcseconds
# G value: 21.8
# Radial Velocity: 92.81
#
# Match - Koposov Star in RV range index value: 17
# Distance: 0.13742933182211498 arcseconds
# G value: 17.5
# Radial Velocity: 99.95
#
# No Match - Koposov star in RV range index value: 18
# Distance: 40.51023481087951 arcseconds
# G value: 22.0
# Radial Velocity: 102.14
#
# Match - Koposov Star in RV range index value: 19
# Distance: 0.10243976758541272 arcseconds
# G value: 19.3
# Radial Velocity: 111.07
#
# Match - Koposov Star in RV range index value: 20
# Distance: 0.24011905971870198 arcseconds
# G value: 19.4
# Radial Velocity: 99.94
#
# Match - Koposov Star in RV range index value: 21
# Distance: 0.25407579652974643 arcseconds
# G value: 20.7
# Radial Velocity: 99.05
#
# No Match - Koposov star in RV range index value: 22
# Distance: 16.92639416549075 arcseconds
# G value: 22.2
# Radial Velocity: 102.67
#
# Match - Koposov Star in RV range index value: 23
# Distance: 0.1858882077073916 arcseconds
# G value: 20.8
# Radial Velocity: 104.7
#
# Match - Koposov Star in RV range index value: 24
# Distance: 0.16638041422818148 arcseconds
# G value: 19.5
# Radial Velocity: 109.8
#
# Match - Koposov Star in RV range index value: 25
# Distance: 0.2245338827034557 arcseconds
# G value: 19.7
# Radial Velocity: 100.03
#
# Match - Koposov Star in RV range index value: 26
# Distance: 0.15994747406268123 arcseconds
# G value: 19.6
# Radial Velocity: 114.36
#
# Match - Koposov Star in RV range index value: 27
# Distance: 0.15811656122421192 arcseconds
# G value: 20.4
# Radial Velocity: 101.64
#
# No Match - Koposov star in RV range index value: 28
# Distance: 36.88355509279218 arcseconds
# G value: 22.3
# Radial Velocity: 107.88
#
# Match - Koposov Star in RV range index value: 29
# Distance: 0.17336717784139472 arcseconds
# G value: 20.6
# Radial Velocity: 108.27
#
# Match - Koposov Star in RV range index value: 30
# Distance: 0.07831787721986683 arcseconds
# G value: 19.7
# Radial Velocity: 99.52
#
# No Match - Koposov star in RV range index value: 31
# Distance: 29.973857783279144 arcseconds
# G value: 21.8
# Radial Velocity: 110.49
#
# Match - Koposov Star in RV range index value: 32
# Distance: 0.1511913973500924 arcseconds
# G value: 19.9
# Radial Velocity: 103.5
#
# Match - Koposov Star in RV range index value: 33
# Distance: 0.06273072567824753 arcseconds
# G value: 19.2
# Radial Velocity: 93.97
#
# No Match - Koposov star in RV range index value: 34
# Distance: 39.99237638091107 arcseconds
# G value: 22.0
# Radial Velocity: 103.6
#
# Match - Koposov Star in RV range index value: 35
# Distance: 0.131961270916721 arcseconds
# G value: 21.2
# Radial Velocity: 101.64
#
# No Match - Koposov star in RV range index value: 36
# Distance: 33.885221674351705 arcseconds
# G value: 21.5
# Radial Velocity: 102.06
#
# Match - Koposov Star in RV range index value: 37
# Distance: 0.2696277134941742 arcseconds
# G value: 20.7
# Radial Velocity: 105.36
#
# Match - Koposov Star in RV range index value: 38
# Distance: 0.11303516489348317 arcseconds
# G value: 21.7
# Radial Velocity: 103.9
#
# Match - Koposov Star in RV range index value: 39
# Distance: 0.07936620247208002 arcseconds
# G value: 20.9
# Radial Velocity: 104.05
#
# Match - Koposov Star in RV range index value: 40
# Distance: 0.04783095543816495 arcseconds
# G value: 21.0
# Radial Velocity: 100.19
#
# Match - Koposov Star in RV range index value: 41
# Distance: 0.1257468331790962 arcseconds
# G value: 20.4
# Radial Velocity: 106.22
#
# Match - Koposov Star in RV range index value: 42
# Distance: 0.09027786026992596 arcseconds
# G value: 20.9
# Radial Velocity: 103.07
#
# No Match - Koposov star in RV range index value: 43
# Distance: 26.25411794809275 arcseconds
# G value: 21.9
# Radial Velocity: 102.33
#
# Match - Koposov Star in RV range index value: 44
# Distance: 0.1681902221163736 arcseconds
# G value: 19.9
# Radial Velocity: 101.19
#
# Match - Koposov Star in RV range index value: 45
# Distance: 0.11985217440374324 arcseconds
# G value: 19.7
# Radial Velocity: 103.55
#
# No Match - Koposov star in RV range index value: 46
# Distance: 19.551027903242378 arcseconds
# G value: 21.5
# Radial Velocity: 114.41
#
# Match - Koposov Star in RV range index value: 47
# Distance: 0.21032044835508032 arcseconds
# G value: 21.3
# Radial Velocity: 91.42
#
# Match - Koposov Star in RV range index value: 48
# Distance: 0.12876362192243954 arcseconds
# G value: 19.6
# Radial Velocity: 101.39
#
# No Match - Koposov star in RV range index value: 49
# Distance: 39.3096701005098 arcseconds
# G value: 21.3
# Radial Velocity: 99.91
#
# No Match - Koposov star in RV range index value: 50
# Distance: 12.50236810535949 arcseconds
# G value: 21.7
# Radial Velocity: 117.33
#
# Match - Koposov Star in RV range index value: 51
# Distance: 0.1374584817632913 arcseconds
# G value: 19.6
# Radial Velocity: 99.39
#
# Match - Koposov Star in RV range index value: 52
# Distance: 0.05561357139566727 arcseconds
# G value: 21.3
# Radial Velocity: 97.21
#
# No Match - Koposov star in RV range index value: 53
# Distance: 10.22593541606831 arcseconds
# G value: 22.1
# Radial Velocity: 102.01
#
# Match - Koposov Star in RV range index value: 54
# Distance: 0.008967549845648933 arcseconds
# G value: 21.0
# Radial Velocity: 90.41
#
# Match - Koposov Star in RV range index value: 55
# Distance: 0.15868244381664534 arcseconds
# G value: 19.5
# Radial Velocity: 93.84
#
# Match - Koposov Star in RV range index value: 56
# Distance: 0.07898265406301781 arcseconds
# G value: 19.6
# Radial Velocity: 98.47
#
# No Match - Koposov star in RV range index value: 57
# Distance: 26.766494530535596 arcseconds
# G value: 21.9
# Radial Velocity: 92.79
#
# No Match - Koposov star in RV range index value: 58
# Distance: 42.366602739746156 arcseconds
# G value: 21.7
# Radial Velocity: 100.02
#
# Match - Koposov Star in RV range index value: 59
# Distance: 0.12152529707750814 arcseconds
# G value: 21.0
# Radial Velocity: 100.22
#
# Match - Koposov Star in RV range index value: 60
# Distance: 0.21910889665177555 arcseconds
# G value: 21.0
# Radial Velocity: 102.16
#
# Match - Koposov Star in RV range index value: 61
# Distance: 0.18017709115816577 arcseconds
# G value: 21.2
# Radial Velocity: 108.1
#
# Match - Koposov Star in RV range index value: 62
# Distance: 0.17898325623115974 arcseconds
# G value: 19.6
# Radial Velocity: 105.37
#
# Match - Koposov Star in RV range index value: 63
# Distance: 0.12817118782010384 arcseconds
# G value: 20.3
# Radial Velocity: 105.68
#
# No Match - Koposov star in RV range index value: 64
# Distance: 25.08721040140653 arcseconds
# G value: 21.4
# Radial Velocity: 98.85
#
# No Match - Koposov star in RV range index value: 65
# Distance: 35.63300522440984 arcseconds
# G value: 21.8
# Radial Velocity: 103.4
# No Match - Koposov star in RV range index value: 66
# Distance: 28.76203865070828 arcseconds
# G value: 22.2
# Radial Velocity: 100.54
#
# Match - Koposov Star in RV range index value: 67
# Distance: 0.04828486899251296 arcseconds
# G value: 19.7
# Radial Velocity: 96.86
#
# Match - Koposov Star in RV range index value: 68
# Distance: 0.06413673713758679 arcseconds
# G value: 17.4
# Radial Velocity: 106.95
#
# Match - Koposov Star in RV range index value: 69
# Distance: 0.17881237270957118 arcseconds
# G value: 19.6
# Radial Velocity: 95.13
#
# No Match - Koposov star in RV range index value: 70
# Distance: 29.54408711858741 arcseconds
# G value: 21.9
# Radial Velocity: 106.83
#
# Match - Koposov Star in RV range index value: 71
# Distance: 0.20259129349809385 arcseconds
# G value: 21.0
# Radial Velocity: 117.74
#
# Match - Koposov Star in RV range index value: 72
# Distance: 0.16720568196649455 arcseconds
# G value: 21.3
# Radial Velocity: 99.13
#
# No Match - Koposov star in RV range index value: 73
# Distance: 16.5026823150643 arcseconds
# G value: 21.7
# Radial Velocity: 103.03
#
# Number of distance matches in RV range: 50
# Number of non distance matches in RV range that did not match: 24

# %%
kopra_fit_byrv_outrange=[] #The lists for positions that are out of the RV range, but fit within the distance difference
kopdec_fit_byrv_outrange=[]

koppmra_fit_fromgaia_byrv_outrange=[] #The lists from gaia that have the proper motions corresponding to 
koppmdec_fit_fromgaia_byrv_outrange=[]
koppmra_error_fit_fromgaia_byrv_outrange=[]
koppmdec_error_fit_fromgaia_byrv_outrange=[]

kopra_nofit_byrv_outrange=[] #The lists for position out of the RV range and out of the distance difference
kopdec_nofit_byrv_outrange=[]

countgood_outrange=0
countbad_outrange=0

for kop in range(len(koposovranofit_byrv)):
    
    dist=10**5
    kopclosera_outrange=koposovranofit_byrv[kop]
    kopclosedec_outrange=koposovdecnofit_byrv[kop]
    
    for gai in range (len(dfra)):
        newdist=np.sqrt((koposovranofit_byrv[kop]-dfra[gai])**2+(koposovdecnofit_byrv[kop]-dfdec[gai])**2)
        if newdist<=dist:
            dist=newdist
            closestpmra_outrange= dfrapm[gai]
            closestpmdec_outrange=dfdecpm[gai]
            closestpmra_error_outrange=dfrapm_error[gai]
            closestpmdec_error_outrange=dfdecpm_error[gai]
    
    if dist<=1/1800:
        countgood_outrange+=1
        kopra_fit_byrv_outrange.append(kopclosera_outrange)
        kopdec_fit_byrv_outrange.append(kopclosedec_outrange)
        koppmra_fit_fromgaia_byrv_outrange.append(closestpmra_outrange)
        koppmdec_fit_fromgaia_byrv_outrange.append(closestpmdec_outrange)
        koppmra_error_fit_fromgaia_byrv_outrange.append(closestpmra_error_outrange)
        koppmdec_error_fit_fromgaia_byrv_outrange.append(closestpmdec_error_outrange)
        print("Match - Koposov Star out of RV range index value:",kop)
        print("Distance:",dist*3600,"arcseconds")
        print("G value:",dfmembergmag[koposovmemberrvworstloc[kop]])
        print("Radial velocity:",dfmemberrvall[koposovmemberrvworstloc[kop]])
        print()
        
    else:
        countbad_outrange+=1
        kopra_nofit_byrv_outrange.append(kopclosera_outrange)
        kopdec_nofit_byrv_outrange.append(kopclosedec_outrange)        
        print("No match - Koposov Star out of RV range index value:",kop)
        print("Distance:",dist*3600,"arcseconds")
        print("G value:",dfmembergmag[koposovmemberrvworstloc[kop]])
        print("Radial velocity:",dfmemberrvall[koposovmemberrvworstloc[kop]])
        print()
        
print("Number of distance matches out of RV range:",countgood_outrange)
print("Number of non distance matches out of RV range:",countbad_outrange)
# Out:
# Match - Koposov Star out of RV range index value: 0
# Distance: 0.23804122887593343 arcseconds
# G value: 17.8
# Radial velocity: -13.5
#
# Match - Koposov Star out of RV range index value: 1
# Distance: 0.2914334405896894 arcseconds
# G value: 19.0
# Radial velocity: 139.12
#
# No match - Koposov Star out of RV range index value: 2
# Distance: 29.794451053701444 arcseconds
# G value: 22.0
# Radial velocity: 77.11
#
# Match - Koposov Star out of RV range index value: 3
# Distance: 0.10287493767908842 arcseconds
# G value: 21.2
# Radial velocity: -228.29
#
# Match - Koposov Star out of RV range index value: 4
# Distance: 0.10163399524801238 arcseconds
# G value: 20.0
# Radial velocity: -19.4
#
# Match - Koposov Star out of RV range index value: 5
# Distance: 0.35885465832988533 arcseconds
# G value: 17.5
# Radial velocity: -49.8
#
# Match - Koposov Star out of RV range index value: 6
# Distance: 0.10591388595712371 arcseconds
# G value: 21.2
# Radial velocity: -137.63
#
# Match - Koposov Star out of RV range index value: 7
# Distance: 0.303366078493439 arcseconds
# G value: 19.9
# Radial velocity: 143.52
#
# Match - Koposov Star out of RV range index value: 8
# Distance: 0.17097430010354922 arcseconds
# G value: 17.7
# Radial velocity: 36.75
#
# Match - Koposov Star out of RV range index value: 9
# Distance: 0.029606260943968014 arcseconds
# G value: 20.9
# Radial velocity: -34.96
#
# No match - Koposov Star out of RV range index value: 10
# Distance: 21.921726173854097 arcseconds
# G value: 21.3
# Radial velocity: 35.47
#
# No match - Koposov Star out of RV range index value: 11
# Distance: 38.76303610356571 arcseconds
# G value: 21.4
# Radial velocity: 82.79
#
# Match - Koposov Star out of RV range index value: 12
# Distance: 0.34665914891128 arcseconds
# G value: 20.7
# Radial velocity: 122.91
#
# No match - Koposov Star out of RV range index value: 13
# Distance: 26.51947180847476 arcseconds
# G value: 22.1
# Radial velocity: -235.57
#
# Match - Koposov Star out of RV range index value: 14
# Distance: 0.05015730660406379 arcseconds
# G value: 21.2
# Radial velocity: -45.51
#
# Match - Koposov Star out of RV range index value: 15
# Distance: 0.2235018235013495 arcseconds
# G value: 17.3
# Radial velocity: -37.63
#
# Match - Koposov Star out of RV range index value: 16
# Distance: 0.25847265506064754 arcseconds
# G value: 19.2
# Radial velocity: -72.15
#
# Match - Koposov Star out of RV range index value: 17
# Distance: 0.03686434886988578 arcseconds
# G value: 19.8
# Radial velocity: 13.06
#
# No match - Koposov Star out of RV range index value: 18
# Distance: 26.978236323057533 arcseconds
# G value: 20.9
# Radial velocity: 224.82
#
# Match - Koposov Star out of RV range index value: 19
# Distance: 0.10224811393290124 arcseconds
# G value: 20.6
# Radial velocity: -28.59
#
# Match - Koposov Star out of RV range index value: 20
# Distance: 0.04601392722881939 arcseconds
# G value: 20.9
# Radial velocity: 79.61
#
# Match - Koposov Star out of RV range index value: 21
# Distance: 0.14056796351442039 arcseconds
# G value: 20.6
# Radial velocity: -90
#
# Match - Koposov Star out of RV range index value: 22
# Distance: 0.6293905546128974 arcseconds
# G value: 18.7
# Radial velocity: 44.92
#
# Match - Koposov Star out of RV range index value: 23
# Distance: 0.23283676198307968 arcseconds
# G value: 18.2
# Radial velocity: 65.88
#
# Match - Koposov Star out of RV range index value: 24
# Distance: 0.20506216984190373 arcseconds
# G value: 18.5
# Radial velocity: -53.39
#
# Match - Koposov Star out of RV range index value: 25
# Distance: 0.15354037727925546 arcseconds
# G value: 19.5
# Radial velocity: -30.74
#
# Match - Koposov Star out of RV range index value: 26
# Distance: 0.19625414519478626 arcseconds
# G value: 18.8
# Radial velocity: 29.74
#
# No match - Koposov Star out of RV range index value: 27
# Distance: 15.546029863566387 arcseconds
# G value: 21.5
# Radial velocity: -117.49
#
# No match - Koposov Star out of RV range index value: 28
# Distance: 38.358740912434016 arcseconds
# G value: 21.9
# Radial velocity: -27.44
#
# No match - Koposov Star out of RV range index value: 29
# Distance: 16.576046299062014 arcseconds
# G value: 21.8
# Radial velocity: 2.25
#
# No match - Koposov Star out of RV range index value: 30
# Distance: 24.989927593264063 arcseconds
# G value: 21.9
# Radial velocity: -43.94
#
# Match - Koposov Star out of RV range index value: 31
# Distance: 0.08270812371454879 arcseconds
# G value: 19.2
# Radial velocity: 6.44
#
# No match - Koposov Star out of RV range index value: 32
# Distance: 20.15468661518825 arcseconds
# G value: 22.4
# Radial velocity: 136.32
#
# No match - Koposov Star out of RV range index value: 33
# Distance: 27.684714074289676 arcseconds
# G value: 21.9
# Radial velocity: 164.05
#
# Match - Koposov Star out of RV range index value: 34
# Distance: 0.0671405119466223 arcseconds
# G value: 19.1
# Radial velocity: -60.56
#
# Match - Koposov Star out of RV range index value: 35
# Distance: 0.06628261814008035 arcseconds
# G value: 18.6
# Radial velocity: -40.08
#
# No match - Koposov Star out of RV range index value: 36
# Distance: 21.505362095201605 arcseconds
# G value: 21.6
# Radial velocity: -123.72
#
# Match - Koposov Star out of RV range index value: 37
# Distance: 0.3667355016385356 arcseconds
# G value: 16.6
# Radial velocity: 42.3
#
# Number of distance matches out of RV range: 26
# Number of non distance matches out of RV range: 12

# %%
martinfitloc=[] #Appending the locations of where the best and worst fits are
martinnofitloc=[] #MARTIN DATA

for i in range (len(martinmember)):
    if martinmember[i]=="y":
        martinfitloc.append(i)
    else:
        martinnofitloc.append(i)

# %%
#converting the RA's and DEC's to numerical degree value

for i in range(len(martinmember)):
    #RA revision
    martinrastr=martinra[i]
    martinrastr=martinrastr.replace(" ","")
    martinra[i]=martinrastr
    
    abra=martinra[i]
    abra=eval(abra[0:2])
    cdra=martinra[i]
    cdra=eval(cdra[2:4])
    efgra=martinra[i]
    efgra=eval(efgra[4:])
    martinra[i]=360*(abra/24+cdra/(24*60)+efgra/(24*60**2))
    
    #Dec revision
    martindecstr=martindec[i]
    martindecstr=martindecstr.replace("+","")
    martindec[i]=martindecstr.replace(" ","")
    
    abdec=martindec[i]
    abdec=eval(abdec[0:2])
    cddec=martindec[i]
    cddec=eval(cddec[2:4])
    efgdec=martindec[i]
    efgdec=eval(efgdec[4:])
    martindec[i]=abdec+(cddec/(60)+efgdec/(60*60))

# %%
martinrafit=[]
martindecfit=[]
martinranofit=[]
martindecnofit=[]

for i in range (len(martinfitloc)):
    martinrafit.append(martinra[martinfitloc[i]])
    martindecfit.append(martindec[martinfitloc[i]])

for i in range (len(martinnofitloc)):
    martinranofit.append(martinra[martinnofitloc[i]])
    martindecnofit.append(martindec[martinnofitloc[i]])

# %%
martinrafit_member=[]
martindecfit_member=[]

martinranofit_member=[]
martindecnofit_member=[]

martinpmra_member=[]
martinpmdec_member=[]
martinpmra_error_member=[]
martinpmdec_error_member=[]

martincountgood_member=0
martincountbad_member=0

for item in range(len(martinfitloc)):
    
    dist=10**3
    martinclosera=martinrafit[item]
    martinclosedec=martindecfit[item]
    
    for gai in range(len(dfra)):
        newdist=np.sqrt((martinclosera-dfra[gai])**2+(martinclosedec-dfdec[gai])**2)
        if newdist<=dist:
            dist=newdist
            closestpmra_martin=dfrapm[gai]
            closestpmdec_martin=dfdecpm[gai]
            closestpmra_error_martin=dfrapm_error[gai]
            closestpmdec_error_martin=dfdecpm_error[gai]
        
    if dist<=1/1800:
        martincountgood_member+=1
        martinrafit_member.append(martinclosera)
        martindecfit_member.append(martinclosedec)
        martinpmra_member.append(closestpmra_martin)
        martinpmdec_member.append(closestpmdec_martin)
        martinpmra_error_member.append(closestpmra_error_martin)
        martinpmdec_error_member.append(closestpmdec_error_martin)
        print("Match - Martin Star in RV range index value:",item)
        print("Distance:",dist*3600,"arcseconds")
        print()
        
    else:
        martincountbad_member+=1
        martinranofit_member.append(martinclosera)
        martindecnofit_member.append(martinclosedec)
        print("No Match - Martin Star in RV range index value:",item)
        print("Distance:",dist*3600,"arcseconds")
        print()
        
print("Number of Martin member distance matches:",martincountgood_member)
print("Number of Martin member distance non-matches:",martincountbad_member)
# Out:
# Match - Martin Star in RV range index value: 0
# Distance: 0.06436246211157055 arcseconds
#
# Match - Martin Star in RV range index value: 1
# Distance: 0.06690210161700917 arcseconds
#
# Match - Martin Star in RV range index value: 2
# Distance: 0.10932528261424047 arcseconds
#
# No Match - Martin Star in RV range index value: 3
# Distance: 33.763803980161846 arcseconds
#
# Match - Martin Star in RV range index value: 4
# Distance: 0.09108113712090803 arcseconds
#
# Match - Martin Star in RV range index value: 5
# Distance: 0.04605333986366843 arcseconds
#
# Match - Martin Star in RV range index value: 6
# Distance: 0.15818536629075108 arcseconds
#
# Match - Martin Star in RV range index value: 7
# Distance: 0.17930267647960343 arcseconds
#
# No Match - Martin Star in RV range index value: 8
# Distance: 42.283603932582665 arcseconds
#
# No Match - Martin Star in RV range index value: 9
# Distance: 40.37311798961203 arcseconds
#
# No Match - Martin Star in RV range index value: 10
# Distance: 40.979907945647994 arcseconds
#
# Match - Martin Star in RV range index value: 11
# Distance: 0.08642371824189402 arcseconds
#
# Match - Martin Star in RV range index value: 12
# Distance: 0.12310039112227115 arcseconds
#
# Match - Martin Star in RV range index value: 13
# Distance: 0.08059476412591242 arcseconds
#
# Match - Martin Star in RV range index value: 14
# Distance: 0.04724745247786257 arcseconds
#
# Match - Martin Star in RV range index value: 15
# Distance: 0.09847377235831223 arcseconds
#
# Match - Martin Star in RV range index value: 16
# Distance: 0.09123108886030404 arcseconds
#
# Match - Martin Star in RV range index value: 17
# Distance: 0.05286020873860108 arcseconds
#
# Match - Martin Star in RV range index value: 18
# Distance: 0.05185824325278345 arcseconds
#
# No Match - Martin Star in RV range index value: 19
# Distance: 30.501711129878625 arcseconds
#
# Match - Martin Star in RV range index value: 20
# Distance: 0.0317096441237288 arcseconds
#
# Match - Martin Star in RV range index value: 21
# Distance: 0.033217533424535324 arcseconds
#
# No Match - Martin Star in RV range index value: 22
# Distance: 19.804875127941383 arcseconds
#
# Match - Martin Star in RV range index value: 23
# Distance: 0.02369350193326055 arcseconds
#
# Match - Martin Star in RV range index value: 24
# Distance: 0.00896754988744392 arcseconds
#
# No Match - Martin Star in RV range index value: 25
# Distance: 8.78891677044933 arcseconds
#
# No Match - Martin Star in RV range index value: 26
# Distance: 29.940379034250604 arcseconds
#
# No Match - Martin Star in RV range index value: 27
# Distance: 39.97313742691824 arcseconds
#
# No Match - Martin Star in RV range index value: 28
# Distance: 17.732172770804716 arcseconds
#
# No Match - Martin Star in RV range index value: 29
# Distance: 26.829348275257242 arcseconds
#
# Number of Martin member distance matches: 19
# Number of Martin member distance non-matches: 11

# %%
martinrafit_nonmember=[]
martindecfit_nonmember=[]

martinranofit_nonmember=[]
martindecnofit_nonmember=[]

martinpmra_nonmember=[]
martinpmdec_nonmember=[]
martinpmra_error_nonmember=[]
martinpmdec_error_nonmember=[]

martincountgood_nonmember=0
martincountbad_nonmember=0

for item in range(len(martinnofitloc)):
    
    dist=10**3
    martinclosera=martinranofit[item]
    martinclosedec=martindecnofit[item]
    
    for gai in range (len(dfra)):
        newdist=np.sqrt((martinclosera-dfra[gai])**2+(martinclosedec-dfdec[gai])**2)
        if newdist<=dist:
            dist=newdist
            closepmra=dfrapm[gai]
            closepmdec=(dfdecpm[gai])
            closepmra_error=(dfrapm_error[gai])
            closepmdec_error=(dfdecpm_error[gai])
    
    if dist<=1/1800:
        martincountgood_nonmember+=1
        martinpmra_nonmember.append(closepmra)
        martinpmdec_nonmember.append(closepmdec)
        martinpmra_error_nonmember.append(closepmra_error)
        martinpmdec_error_nonmember.append(closepmdec_error)
        martinrafit_nonmember.append(martinclosera)
        martindecfit_nonmember.append(martinclosedec)
        print("Match - Non-Member Martin star index value:", item)
        print("Distance:",dist*3600,"arcseconds")
        print()
        
    else:
        martincountbad_nonmember+=1
        martinranofit_nonmember.append(martinclosera)
        martindecnofit_nonmember.append(martinclosedec)
        print("No Match - Non-Member Martin star index value:",item)
        print("Distance:",dist*3600,"arcseconds")
        print()

print("Number of Martin non-member distance matches:",martincountgood_nonmember)
print("Number of Martin non-member distance non-matches",martincountbad_nonmember)
# Out:
# Match - Non-Member Martin star index value: 0
# Distance: 0.32260635689332523 arcseconds
#
# Match - Non-Member Martin star index value: 1
# Distance: 0.2476322045598754 arcseconds
#
# Match - Non-Member Martin star index value: 2
# Distance: 0.12421220491500785 arcseconds
#
# Match - Non-Member Martin star index value: 3
# Distance: 0.20118880086010257 arcseconds
#
# Match - Non-Member Martin star index value: 4
# Distance: 0.0575161204114317 arcseconds
#
# Match - Non-Member Martin star index value: 5
# Distance: 0.30509366412950667 arcseconds
#
# Match - Non-Member Martin star index value: 6
# Distance: 0.14193887756145832 arcseconds
#
# No Match - Non-Member Martin star index value: 7
# Distance: 24.141853308397987 arcseconds
#
# No Match - Non-Member Martin star index value: 8
# Distance: 18.786682589694557 arcseconds
#
# Match - Non-Member Martin star index value: 9
# Distance: 0.17748353875311607 arcseconds
#
# Match - Non-Member Martin star index value: 10
# Distance: 0.18111985780134873 arcseconds
#
# Match - Non-Member Martin star index value: 11
# Distance: 0.09562161060221715 arcseconds
#
# Match - Non-Member Martin star index value: 12
# Distance: 0.14870973864136733 arcseconds
#
# Match - Non-Member Martin star index value: 13
# Distance: 0.4839819897808395 arcseconds
#
# Match - Non-Member Martin star index value: 14
# Distance: 0.2167117971210472 arcseconds
#
# Match - Non-Member Martin star index value: 15
# Distance: 0.3154789592887862 arcseconds
#
# Match - Non-Member Martin star index value: 16
# Distance: 0.3692762349568487 arcseconds
#
# Match - Non-Member Martin star index value: 17
# Distance: 0.35810421207790977 arcseconds
#
# Match - Non-Member Martin star index value: 18
# Distance: 0.28846928168365366 arcseconds
#
# Match - Non-Member Martin star index value: 19
# Distance: 0.05679443717917352 arcseconds
#
# Match - Non-Member Martin star index value: 20
# Distance: 0.10650548047066398 arcseconds
#
# Match - Non-Member Martin star index value: 21
# Distance: 0.23123141549927823 arcseconds
#
# Match - Non-Member Martin star index value: 22
# Distance: 0.14480843548467184 arcseconds
#
# Match - Non-Member Martin star index value: 23
# Distance: 0.16723766540542223 arcseconds
#
# Match - Non-Member Martin star index value: 24
# Distance: 0.2171521598124567 arcseconds
#
# Match - Non-Member Martin star index value: 25
# Distance: 0.48222944479644436 arcseconds
#
# Match - Non-Member Martin star index value: 26
# Distance: 0.13023408299351916 arcseconds
#
# Match - Non-Member Martin star index value: 27
# Distance: 0.25092787260196736 arcseconds
#
# Match - Non-Member Martin star index value: 28
# Distance: 0.1758143896128268 arcseconds
#
# Match - Non-Member Martin star index value: 29
# Distance: 0.0992864942218743 arcseconds
#
# Match - Non-Member Martin star index value: 30
# Distance: 0.23993799478901098 arcseconds
#
# Match - Non-Member Martin star index value: 31
# Distance: 0.19020451496948196 arcseconds
#
# Match - Non-Member Martin star index value: 32
# Distance: 0.1476307957776402 arcseconds
#
# Match - Non-Member Martin star index value: 33
# Distance: 0.3199391190509918 arcseconds
#
# Match - Non-Member Martin star index value: 34
# Distance: 0.4493190727915379 arcseconds
#
# Match - Non-Member Martin star index value: 35
# Distance: 0.6433779318651055 arcseconds
#
# Match - Non-Member Martin star index value: 36
# Distance: 0.277407054505226 arcseconds
#
# Match - Non-Member Martin star index value: 37
# Distance: 0.19266757679697544 arcseconds
#
# Match - Non-Member Martin star index value: 38
# Distance: 0.06098927362826289 arcseconds
#
# Match - Non-Member Martin star index value: 39
# Distance: 0.2301267363828872 arcseconds
#
# Match - Non-Member Martin star index value: 40
# Distance: 0.07479168347505216 arcseconds
#
# Match - Non-Member Martin star index value: 41
# Distance: 0.20512123693059034 arcseconds
#
# Match - Non-Member Martin star index value: 42
# Distance: 0.02741055642601837 arcseconds
#
# Match - Non-Member Martin star index value: 43
# Distance: 0.21915636203342254 arcseconds
#
# No Match - Non-Member Martin star index value: 44
# Distance: 69.0990006518746 arcseconds
#
# No Match - Non-Member Martin star index value: 45
# Distance: 19.651571049020355 arcseconds
#
# No Match - Non-Member Martin star index value: 46
# Distance: 40.38534942993853 arcseconds
#
# No Match - Non-Member Martin star index value: 47
# Distance: 45.09775810721797 arcseconds
#
# No Match - Non-Member Martin star index value: 48
# Distance: 22.74134993437956 arcseconds
#
# Match - Non-Member Martin star index value: 49
# Distance: 0.10332308747693729 arcseconds
#
# Match - Non-Member Martin star index value: 50
# Distance: 0.2353746287438626 arcseconds
#
# Match - Non-Member Martin star index value: 51
# Distance: 0.10785513039437065 arcseconds
#
# Match - Non-Member Martin star index value: 52
# Distance: 0.08031675779456153 arcseconds
#
# Match - Non-Member Martin star index value: 53
# Distance: 0.5421807514713971 arcseconds
#
# Match - Non-Member Martin star index value: 54
# Distance: 0.7661236294859741 arcseconds
#
# Match - Non-Member Martin star index value: 55
# Distance: 0.20133582244315187 arcseconds
#
# Match - Non-Member Martin star index value: 56
# Distance: 0.047998949933645334 arcseconds
#
# Match - Non-Member Martin star index value: 57
# Distance: 0.31716963054590297 arcseconds
#
# Match - Non-Member Martin star index value: 58
# Distance: 0.13488464252648066 arcseconds
#
# Match - Non-Member Martin star index value: 59
# Distance: 0.20272942318514167 arcseconds
#
# Match - Non-Member Martin star index value: 60
# Distance: 0.19986829001303363 arcseconds
#
# Match - Non-Member Martin star index value: 61
# Distance: 0.22988658783139662 arcseconds
#
# Match - Non-Member Martin star index value: 62
# Distance: 1.659152011409165 arcseconds
#
# Match - Non-Member Martin star index value: 63
# Distance: 0.055880624979667774 arcseconds
#
# Match - Non-Member Martin star index value: 64
# Distance: 0.18840698396887243 arcseconds
#
# Match - Non-Member Martin star index value: 65
# Distance: 0.5246065300927816 arcseconds
#
# Number of Martin non-member distance matches: 59
# Number of Martin non-member distance non-matches 7

# %%
#Norris Data begins here, Munoz didn't have stars readily available

norrismembloc=[]
norrisnonmembloc=[]

#Appending the best fit locations to lists

for i in range (len(norrismember)):
    if norrismember[i]=="M":
        norrismembloc.append(i)
    else:
        norrisnonmembloc.append(i)

# %%
#converting the RA's and Dec's into decimal degree value

for i in range (len(norrismember)):

    #RA
    
    norrisrastr=norrisra[i]
    norrisra[i]=100*eval(norrisrastr.replace(" ",""))
    norrisra[i]=str(int((norrisra[i]+0.005)*100)/100)
    
    abra=norrisra[i]
    abra=eval(abra[0:2])
    cdra=norrisra[i]
    if cdra[2]=="0":
        cdra=eval(cdra[3])
    else:
        cdra=eval(cdra[2:4])
    
    efgra=norrisra[i]
    if efgra[4]=="0":
        if efgra[5]=="0":
            efgra=eval(efgra[6:])/100
        else:
            efgra=eval(efgra[5:])/100
    else:
        efgra=eval(efgra[4:])/100
    
    norrisra[i]=360*(abra/24+cdra/(24*60)+efgra/(24*60*60))
    
    #DEC
    
    norrisdecstr=norrisdec[i]
    norrisdecstr=norrisdecstr.replace("+","")
    norrisdec[i]=10*eval(norrisdecstr.replace(" ",""))
    norrisdec[i]=str(int((norrisdec[i]+0.005)*100)/100)
    
    abdec=norrisdec[i]
    abdec=eval(abdec[0:2])
    cddec=norrisdec[i]
    if cddec[2]=="0":
        cddec=eval(cddec[3])
    else:
        cddec=eval(cddec[2:4])
    efgdec=norrisdec[i]
    if efgdec[4]=="0":
        if efgdec[5]=="0":
            efgdec=eval(efgdec[6:])/10
        else:
            efgdec=eval(efgdec[5:])/10
    else:
        efgdec=eval(efgdec[4:])/10
        
    norrisdec[i]=abdec+cddec/60+efgdec/(60**2)
    
    
for i in range(len(norrisra)):
    print("RA:",norrisra[i])
    print("Dec:",norrisdec[i])
    print()
# Out:
# RA: 209.7597083333333
# Dec: 14.506444444444444
#
# RA: 209.74991666666665
# Dec: 14.394583333333333
#
# RA: 209.89804166666661
# Dec: 14.339916666666667
#
# RA: 209.91091666666662
# Dec: 14.321083333333332
#
# RA: 209.95337499999997
# Dec: 14.328583333333333
#
# RA: 210.00641666666667
# Dec: 14.365055555555555
#
# RA: 210.0294166666667
# Dec: 14.340833333333334
#
# RA: 210.048875
# Dec: 14.417055555555555
#
# RA: 210.08795833333335
# Dec: 14.291083333333333
#
# RA: 210.10762500000004
# Dec: 14.435444444444444
#
# RA: 210.10908333333336
# Dec: 14.458194444444445
#
# RA: 210.1699166666667
# Dec: 14.289444444444444
#
# RA: 209.83529166666662
# Dec: 14.749138888888888
#
# RA: 210.13333333333335
# Dec: 14.717361111111112
#
# RA: 210.16825000000003
# Dec: 14.762472222222222
#
# RA: 209.90329166666663
# Dec: 14.194666666666667
#
# RA: 209.9008333333333
# Dec: 14.247888888888887
#
# RA: 209.93087499999996
# Dec: 14.267111111111111
#
# RA: 210.01258333333334
# Dec: 14.209999999999999
#
# RA: 210.11895833333335
# Dec: 14.229000000000001
#
# RA: 210.06137500000003
# Dec: 14.220527777777779
#
# RA: 209.71154166666665
# Dec: 14.591777777777779
#
# RA: 209.73324999999997
# Dec: 14.676416666666666
#
# RA: 209.81391666666664
# Dec: 14.598
#
# RA: 209.8985833333333
# Dec: 14.62638888888889
#
# RA: 209.83904166666665
# Dec: 14.60175
#
# RA: 210.1312916666667
# Dec: 14.567666666666666
#
# RA: 209.7838333333333
# Dec: 14.541138888888888
#
# RA: 210.05383333333333
# Dec: 14.553277777777778
#
# RA: 210.09570833333333
# Dec: 14.5125
#
# RA: 210.04370833333337
# Dec: 14.529305555555556
#
# RA: 210.1521666666667
# Dec: 14.657583333333333
#
# RA: 210.06070833333337
# Dec: 14.597972222222223
#
# RA: 209.9540833333333
# Dec: 14.501722222222222
#
# RA: 209.91404166666663
# Dec: 14.444
#
# RA: 209.9430833333333
# Dec: 14.419944444444443
#
# RA: 209.7205
# Dec: 14.418138888888889
#
# RA: 209.87479166666665
# Dec: 14.249083333333333
#
# RA: 210.175625
# Dec: 14.255666666666666
#
# RA: 209.78791666666663
# Dec: 14.55313888888889
#
# RA: 210.96695833333337
# Dec: 14.242638888888887
#
# RA: 210.8661666666667
# Dec: 14.25286111111111
#
# RA: 210.93758333333335
# Dec: 14.809416666666667
#
# RA: 210.857375
# Dec: 14.385055555555555
#
# RA: 210.82850000000002
# Dec: 14.307111111111112
#
# RA: 210.76387499999998
# Dec: 13.952444444444444
#
# RA: 210.77325000000002
# Dec: 14.522083333333335
#
# RA: 210.67470833333334
# Dec: 14.082333333333333
#
# RA: 210.72245833333335
# Dec: 14.533138888888889
#
# RA: 210.60000000000002
# Dec: 13.8545
#
# RA: 210.55916666666667
# Dec: 13.831777777777777
#
# RA: 210.59858333333332
# Dec: 14.157944444444444
#
# RA: 210.61312500000003
# Dec: 14.386944444444444
#
# RA: 210.57925000000003
# Dec: 14.307027777777778
#
# RA: 210.41641666666666
# Dec: 13.598638888888889
#
# RA: 210.37670833333334
# Dec: 13.815722222222224
#
# RA: 210.42462500000002
# Dec: 14.145277777777777
#
# RA: 210.42720833333337
# Dec: 14.255583333333334
#
# RA: 210.32162500000004
# Dec: 13.645305555555556
#
# RA: 210.43916666666667
# Dec: 14.698527777777779
#
# RA: 210.27433333333335
# Dec: 13.646222222222221
#
# RA: 210.36395833333336
# Dec: 14.412194444444445
#
# RA: 210.34325
# Dec: 14.290083333333333
#
# RA: 210.41770833333334
# Dec: 14.805611111111112
#
# RA: 210.46662500000002
# Dec: 15.181944444444444
#
# RA: 210.459125
# Dec: 15.335027777777778
#
# RA: 210.20954166666667
# Dec: 13.759
#
# RA: 210.27225
# Dec: 14.199055555555557
#
# RA: 210.38533333333336
# Dec: 14.95647222222222
#
# RA: 210.23516666666666
# Dec: 14.04813888888889
#
# RA: 210.206125
# Dec: 13.905444444444445
#
# RA: 210.12770833333335
# Dec: 13.538555555555556
#
# RA: 210.15508333333335
# Dec: 13.937861111111111
#
# RA: 210.07116666666667
# Dec: 13.65911111111111
#
# RA: 210.21420833333337
# Dec: 15.011583333333334
#
# RA: 210.07204166666668
# Dec: 14.16013888888889
#
# RA: 209.98104166666664
# Dec: 13.528833333333335
#
# RA: 210.03954166666668
# Dec: 13.972583333333333
#
# RA: 209.9564583333333
# Dec: 13.741638888888888
#
# RA: 210.02695833333334
# Dec: 14.27513888888889
#
# RA: 210.1552916666667
# Dec: 15.205055555555555
#
# RA: 209.91054166666663
# Dec: 13.643638888888889
#
# RA: 210.0045
# Dec: 14.614305555555555
#
# RA: 209.91279166666666
# Dec: 14.004055555555556
#
# RA: 209.97399999999996
# Dec: 14.515555555555556
#
# RA: 209.87654166666664
# Dec: 14.047555555555556
#
# RA: 209.8028333333333
# Dec: 13.715499999999999
#
# RA: 209.83004166666666
# Dec: 13.945277777777777
#
# RA: 209.81341666666663
# Dec: 13.869944444444444
#
# RA: 209.83529166666662
# Dec: 14.139
#
# RA: 209.90783333333331
# Dec: 15.194305555555555
#
# RA: 209.68420833333332
# Dec: 13.684944444444445
#
# RA: 209.72174999999996
# Dec: 14.116055555555555
#
# RA: 209.64337499999996
# Dec: 13.702083333333333
#
# RA: 209.6377083333333
# Dec: 13.821472222222223
#
# RA: 209.5995833333333
# Dec: 13.920777777777777
#
# RA: 209.56841666666662
# Dec: 13.713722222222222
#
# RA: 209.6554583333333
# Dec: 14.390555555555554
#
# RA: 209.59920833333328
# Dec: 14.022083333333335
#
# RA: 209.6409166666666
# Dec: 14.352361111111112
#
# RA: 209.5248333333333
# Dec: 13.938777777777778
#
# RA: 209.58612499999998
# Dec: 14.417694444444443
#
# RA: 209.63362499999997
# Dec: 14.76752777777778
#
# RA: 209.64854166666663
# Dec: 15.084666666666667
#
# RA: 209.50658333333328
# Dec: 14.156944444444445
#
# RA: 209.42412499999998
# Dec: 13.787916666666666
#
# RA: 209.41687499999995
# Dec: 14.034666666666666
#
# RA: 209.39837499999996
# Dec: 13.95136111111111
#
# RA: 209.42599999999996
# Dec: 14.162194444444445
#
# RA: 209.4254583333333
# Dec: 14.207722222222221
#
# RA: 209.54374999999996
# Dec: 15.080666666666666
#
# RA: 209.3863333333333
# Dec: 14.263638888888888
#
# RA: 209.36966666666663
# Dec: 14.308416666666668
#
# RA: 209.36458333333331
# Dec: 14.28411111111111
#
# RA: 209.26120833333331
# Dec: 13.988416666666666
#
# RA: 209.21091666666663
# Dec: 13.900555555555556
#
# RA: 209.20454166666664
# Dec: 13.98561111111111
#
# RA: 209.21095833333334
# Dec: 14.532972222222224
#
# RA: 209.14591666666666
# Dec: 14.187027777777779
#
# RA: 209.1507083333333
# Dec: 14.404166666666667
#
# RA: 209.0800833333333
# Dec: 14.097000000000001
#
# RA: 209.081
# Dec: 14.373777777777779

# %%
#Finding the RA's and Dec's of members and non members, and putting them into lists

norrisramember=[]
norrisdecmember=[]
norrisranonmember=[]
norrisdecnonmember=[]

for i in range (len(norrismembloc)):
    norrisramember.append(norrisra[norrismembloc[i]])
    norrisdecmember.append(norrisdec[norrismembloc[i]])
for i in range(len(norrisnonmembloc)):
    norrisranonmember.append(norrisra[norrisnonmembloc[i]])
    norrisdecnonmember.append(norrisdec[norrisnonmembloc[i]])
    
for i in range (len(norrisramember)):
    print("RA:",norrisramember[i])
    print("Dec:",norrisdecmember[i])
    print()
# Out:
# RA: 209.89804166666661
# Dec: 14.339916666666667
#
# RA: 209.91091666666662
# Dec: 14.321083333333332
#
# RA: 209.95337499999997
# Dec: 14.328583333333333
#
# RA: 210.048875
# Dec: 14.417055555555555
#
# RA: 210.08795833333335
# Dec: 14.291083333333333
#
# RA: 210.10762500000004
# Dec: 14.435444444444444
#
# RA: 210.06137500000003
# Dec: 14.220527777777779
#
# RA: 210.1312916666667
# Dec: 14.567666666666666
#
# RA: 210.04370833333337
# Dec: 14.529305555555556
#
# RA: 210.1521666666667
# Dec: 14.657583333333333
#
# RA: 210.06070833333337
# Dec: 14.597972222222223
#
# RA: 209.9540833333333
# Dec: 14.501722222222222
#
# RA: 210.0045
# Dec: 14.614305555555555
#
# RA: 209.8028333333333
# Dec: 13.715499999999999
#
# RA: 209.72174999999996
# Dec: 14.116055555555555
#
# RA: 209.6409166666666
# Dec: 14.352361111111112

# %%
#Distance matching for Martin members

norrisrafit_member=[]
norrisdecfit_member=[]

norrisranofit_member=[]
norrisdecnofit_member=[]

norrispmra_member=[]
norrispmdec_member=[]
norrispmra_error_member=[]
norrispmdec_error_member=[]

norrismembergoodcount=0
norrismemberbadcount=0

for item in range(len(norrismembloc)):
    dist=10**3
    norrisclosera=norrisramember[item]
    norrisclosedec=norrisdecmember[item]
    
    for gai in range (len(dfra)):
        newdist=np.sqrt((norrisclosedec-dfdec[gai])**2+(norrisclosera-dfra[gai])**2)
        if newdist<=dist:
            dist=newdist
            closepmra_norris=dfrapm[gai]
            closepmdec_norris=dfdecpm[gai]
            closepmra_error_norris=dfrapm_error[gai]
            closepmdec_error_norris=dfdecpm_error[gai]

    if dist<=1/1800:
        norrismembergoodcount+=1
        print("Match - Norris member star index value:",item)
        print("Distance:",dist*3600,"arcseconds")
        print()
        norrispmra_member.append(closepmra_norris)
        norrispmdec_member.append(closepmdec_norris)
        norrispmra_error_member.append(closepmra_error_norris)
        norrispmdec_error_member.append(closepmdec_error_norris)
        norrisrafit_member.append(norrisclosera)
        norrisdecfit_member.append(norrisclosedec)
    else:
        norrismemberbadcount+=1
        norrisranofit_member.append(norrisclosera)
        norrisdecnofit_member.append(norrisclosedec)
        print("No Match - Norris member star index value:",item)
        print("Distance:",dist*3600,"arcseconds")
        print()

print("Number of Norris distance matches:",norrismembergoodcount)
print("Number of Norris distance non-matches:",norrismemberbadcount)
# Out:
# Match - Norris member star index value: 0
# Distance: 0.12401056724271922 arcseconds
#
# Match - Norris member star index value: 1
# Distance: 0.12014657446972554 arcseconds
#
# Match - Norris member star index value: 2
# Distance: 0.10357422671657428 arcseconds
#
# Match - Norris member star index value: 3
# Distance: 0.10209030751665958 arcseconds
#
# Match - Norris member star index value: 4
# Distance: 0.06298699667477237 arcseconds
#
# Match - Norris member star index value: 5
# Distance: 0.02369350193326055 arcseconds
#
# Match - Norris member star index value: 6
# Distance: 0.029428534849443952 arcseconds
#
# Match - Norris member star index value: 7
# Distance: 0.10352106577597074 arcseconds
#
# Match - Norris member star index value: 8
# Distance: 0.06436246211157055 arcseconds
#
# Match - Norris member star index value: 9
# Distance: 0.05397218170314721 arcseconds
#
# Match - Norris member star index value: 10
# Distance: 0.12749316511946973 arcseconds
#
# Match - Norris member star index value: 11
# Distance: 0.10060097071459474 arcseconds
#
# Match - Norris member star index value: 12
# Distance: 0.15359108597396842 arcseconds
#
# Match - Norris member star index value: 13
# Distance: 0.10843588088452487 arcseconds
#
# Match - Norris member star index value: 14
# Distance: 0.04571645140445618 arcseconds
#
# Match - Norris member star index value: 15
# Distance: 0.1097310374721259 arcseconds
#
# Number of Norris distance matches: 16
# Number of Norris distance non-matches: 0

# %%
#Distance matching for Martin nonmembers

norrisrafit_nonmember=[]
norrisdecfit_nonmember=[]

norrisranofit_nonmember=[]
norrisdecnofit_nonmember=[]

norrispmra_nonmember=[]
norrispmdec_nonmember=[]
norrispmra_error_nonmember=[]
norrispmdec_error_nonmember=[]

norrisnonmember_goodcount=0
norrisnonmember_badcount=0

for item in range(len(norrisnonmembloc)):
    dist=10**3
    norrisclosera=norrisranonmember[item]
    norrisclosedec=norrisdecnonmember[item]
    
    for gai in range(len(dfra)):
        newdist=np.sqrt((norrisclosera-dfra[gai])**2+(norrisclosedec-dfdec[gai])**2)
        if newdist<=dist:
            dist=newdist
            closepmra_norris=dfrapm[gai]
            closepmdec_norris=dfdecpm[gai]
            closepmra_error_norris=dfrapm_error[gai]
            closepmdec_error_norris=dfdecpm_error[gai]
    
    if newdist<=1/1800:
        
        norrisrafit_nonmember.append(norrisclosera)
        norrisdecfit_nonmember.append(norrisclosedec)
        norrispmra_nonmember.append(closepmra_norris)
        norrispmdec_nonmember.append(closepmdec_norris)
        norrispmra_error_nonmember.append(closepmra_error_norris)
        norrispmdec_error_nonmember.append(closepmdec_error_norris)
        print("Match - Norris non-member star index value:",item)
        print("Distance:",dist*3600,"arcseconds")
        print()
        norrisnonmember_goodcount+=1
    else:
        
        norrisranofit_nonmember.append(norrisclosera)
        norrisdecnofit_nonmember.append(norrisclosedec)
        print("No Match - Norris non-member star index value:",item)
        print("Distance:",dist*3600,"arcseconds")
        print()
        norrisnonmember_badcount+=1
        
print("Number of Norris non-member distance matches:", norrisnonmember_goodcount)
print("Number of Norris non-member distance non-matches", norrisnonmember_badcount)
# Out:
# No Match - Norris non-member star index value: 0
# Distance: 0.016354046173693994 arcseconds
#
# No Match - Norris non-member star index value: 1
# Distance: 0.04738314038050841 arcseconds
#
# No Match - Norris non-member star index value: 2
# Distance: 0.10489631224646251 arcseconds
#
# No Match - Norris non-member star index value: 3
# Distance: 0.12090006059363934 arcseconds
#
# No Match - Norris non-member star index value: 4
# Distance: 0.21915636203342254 arcseconds
#
# No Match - Norris non-member star index value: 5
# Distance: 0.1945262622471259 arcseconds
#
# No Match - Norris non-member star index value: 6
# Distance: 0.08608667441549331 arcseconds
#
# No Match - Norris non-member star index value: 7
# Distance: 0.07737882625774019 arcseconds
#
# No Match - Norris non-member star index value: 8
# Distance: 0.18520342318859462 arcseconds
#
# No Match - Norris non-member star index value: 9
# Distance: 0.07382432430856162 arcseconds
#
# No Match - Norris non-member star index value: 10
# Distance: 0.18025030044214585 arcseconds
#
# No Match - Norris non-member star index value: 11
# Distance: 0.2949523414606871 arcseconds
#
# No Match - Norris non-member star index value: 12
# Distance: 0.04581809086520295 arcseconds
#
# No Match - Norris non-member star index value: 13
# Distance: 0.1503096416080434 arcseconds
#
# No Match - Norris non-member star index value: 14
# Distance: 0.2726268897544487 arcseconds
#
# No Match - Norris non-member star index value: 15
# Distance: 0.21251869468947696 arcseconds
#
# No Match - Norris non-member star index value: 16
# Distance: 0.33963842526760935 arcseconds
#
# No Match - Norris non-member star index value: 17
# Distance: 0.06549757122196039 arcseconds
#
# No Match - Norris non-member star index value: 18
# Distance: 0.15539170317617612 arcseconds
#
# No Match - Norris non-member star index value: 19
# Distance: 0.23743756206042668 arcseconds
#
# No Match - Norris non-member star index value: 20
# Distance: 0.06690210161700917 arcseconds
#
# No Match - Norris non-member star index value: 21
# Distance: 0.20118880086010257 arcseconds
#
# No Match - Norris non-member star index value: 22
# Distance: 0.09847377235831223 arcseconds
#
# No Match - Norris non-member star index value: 23
# Distance: 0.04532790066496594 arcseconds
#
# No Match - Norris non-member star index value: 24
# Distance: 0.06726996165604548 arcseconds
#
# No Match - Norris non-member star index value: 25
# Distance: 0.047736100480228416 arcseconds
#
# No Match - Norris non-member star index value: 26
# Distance: 0.15784963459612258 arcseconds
#
# No Match - Norris non-member star index value: 27
# Distance: 0.11114277711898668 arcseconds
#
# No Match - Norris non-member star index value: 28
# Distance: 0.20139368548216327 arcseconds
#
# No Match - Norris non-member star index value: 29
# Distance: 0.08829164492877725 arcseconds
#
# No Match - Norris non-member star index value: 30
# Distance: 0.1577231980667025 arcseconds
#
# No Match - Norris non-member star index value: 31
# Distance: 0.10211517139170313 arcseconds
#
# No Match - Norris non-member star index value: 32
# Distance: 0.07316480330798408 arcseconds
#
# No Match - Norris non-member star index value: 33
# Distance: 0.22114148830781238 arcseconds
#
# No Match - Norris non-member star index value: 34
# Distance: 0.09902368960602062 arcseconds
#
# No Match - Norris non-member star index value: 35
# Distance: 0.13818524915332012 arcseconds
#
# No Match - Norris non-member star index value: 36
# Distance: 0.17966592824410094 arcseconds
#
# No Match - Norris non-member star index value: 37
# Distance: 0.21502554770842291 arcseconds
#
# No Match - Norris non-member star index value: 38
# Distance: 0.2022705295371295 arcseconds
#
# No Match - Norris non-member star index value: 39
# Distance: 0.2016678651655177 arcseconds
#
# No Match - Norris non-member star index value: 40
# Distance: 0.27278674820278936 arcseconds
#
# No Match - Norris non-member star index value: 41
# Distance: 0.1641055718431476 arcseconds
#
# No Match - Norris non-member star index value: 42
# Distance: 0.1795816915914951 arcseconds
#
# No Match - Norris non-member star index value: 43
# Distance: 0.18620756574664202 arcseconds
#
# No Match - Norris non-member star index value: 44
# Distance: 0.22021698119777788 arcseconds
#
# No Match - Norris non-member star index value: 45
# Distance: 0.19338024183024877 arcseconds
#
# No Match - Norris non-member star index value: 46
# Distance: 0.10632341257187355 arcseconds
#
# No Match - Norris non-member star index value: 47
# Distance: 0.1372564712996134 arcseconds
#
# No Match - Norris non-member star index value: 48
# Distance: 0.16583030950350405 arcseconds
#
# No Match - Norris non-member star index value: 49
# Distance: 0.1426288110272482 arcseconds
#
# No Match - Norris non-member star index value: 50
# Distance: 0.15853668754204234 arcseconds
#
# No Match - Norris non-member star index value: 51
# Distance: 0.26533346330111435 arcseconds
#
# No Match - Norris non-member star index value: 52
# Distance: 0.18424482929696834 arcseconds
#
# No Match - Norris non-member star index value: 53
# Distance: 0.14248235173271773 arcseconds
#
# No Match - Norris non-member star index value: 54
# Distance: 0.10889749765270734 arcseconds
#
# No Match - Norris non-member star index value: 55
# Distance: 0.1877380043501848 arcseconds
#
# No Match - Norris non-member star index value: 56
# Distance: 0.397587207855198 arcseconds
#
# No Match - Norris non-member star index value: 57
# Distance: 0.13345633927538403 arcseconds
#
# No Match - Norris non-member star index value: 58
# Distance: 0.2135504338855583 arcseconds
#
# No Match - Norris non-member star index value: 59
# Distance: 0.11287173226220101 arcseconds
#
# No Match - Norris non-member star index value: 60
# Distance: 0.11308691175049362 arcseconds
#
# No Match - Norris non-member star index value: 61
# Distance: 0.05574342100851311 arcseconds
#
# No Match - Norris non-member star index value: 62
# Distance: 0.1699611888695788 arcseconds
#
# No Match - Norris non-member star index value: 63
# Distance: 0.28341267237540474 arcseconds
#
# No Match - Norris non-member star index value: 64
# Distance: 0.06913118837828268 arcseconds
#
# No Match - Norris non-member star index value: 65
# Distance: 0.045902128750784726 arcseconds
#
# No Match - Norris non-member star index value: 66
# Distance: 0.14677857725915852 arcseconds
#
# No Match - Norris non-member star index value: 67
# Distance: 0.1019576149442101 arcseconds
#
# No Match - Norris non-member star index value: 68
# Distance: 0.14911190279456624 arcseconds
#
# No Match - Norris non-member star index value: 69
# Distance: 0.1901428374600966 arcseconds
#
# No Match - Norris non-member star index value: 70
# Distance: 0.1537470137441436 arcseconds
#
# No Match - Norris non-member star index value: 71
# Distance: 0.30509366412950667 arcseconds
#
# No Match - Norris non-member star index value: 72
# Distance: 0.21323295391596522 arcseconds
#
# No Match - Norris non-member star index value: 73
# Distance: 0.0981513339701215 arcseconds
#
# No Match - Norris non-member star index value: 74
# Distance: 0.03356614288362517 arcseconds
#
# No Match - Norris non-member star index value: 75
# Distance: 0.18116108217533528 arcseconds
#
# No Match - Norris non-member star index value: 76
# Distance: 0.11378960865370083 arcseconds
#
# No Match - Norris non-member star index value: 77
# Distance: 0.14627914910246587 arcseconds
#
# No Match - Norris non-member star index value: 78
# Distance: 0.1489136748648892 arcseconds
#
# No Match - Norris non-member star index value: 79
# Distance: 0.1769082225187646 arcseconds
#
# No Match - Norris non-member star index value: 80
# Distance: 0.20506480022327098 arcseconds
#
# No Match - Norris non-member star index value: 81
# Distance: 0.1888847942910854 arcseconds
#
# No Match - Norris non-member star index value: 82
# Distance: 0.12791077245843707 arcseconds
#
# No Match - Norris non-member star index value: 83
# Distance: 0.14317286506634885 arcseconds
#
# No Match - Norris non-member star index value: 84
# Distance: 0.10891323766589177 arcseconds
#
# No Match - Norris non-member star index value: 85
# Distance: 0.15903890603634088 arcseconds
#
# No Match - Norris non-member star index value: 86
# Distance: 0.16727895115265534 arcseconds
#
# No Match - Norris non-member star index value: 87
# Distance: 0.2201027530063906 arcseconds
#
# No Match - Norris non-member star index value: 88
# Distance: 0.183003578835027 arcseconds
#
# No Match - Norris non-member star index value: 89
# Distance: 0.12916182723244862 arcseconds
#
# No Match - Norris non-member star index value: 90
# Distance: 0.1678428526463538 arcseconds
#
# No Match - Norris non-member star index value: 91
# Distance: 0.05361825775219071 arcseconds
# No Match - Norris non-member star index value: 92
# Distance: 0.2655140498016383 arcseconds
#
# No Match - Norris non-member star index value: 93
# Distance: 0.13484487226120867 arcseconds
#
# No Match - Norris non-member star index value: 94
# Distance: 0.1358216371060198 arcseconds
#
# No Match - Norris non-member star index value: 95
# Distance: 0.17927467398684216 arcseconds
#
# No Match - Norris non-member star index value: 96
# Distance: 0.1298406367438751 arcseconds
#
# No Match - Norris non-member star index value: 97
# Distance: 0.09229078212179696 arcseconds
#
# No Match - Norris non-member star index value: 98
# Distance: 0.2145161131382155 arcseconds
#
# No Match - Norris non-member star index value: 99
# Distance: 0.20382416790056176 arcseconds
#
# No Match - Norris non-member star index value: 100
# Distance: 0.5826803910183525 arcseconds
#
# No Match - Norris non-member star index value: 101
# Distance: 0.08919485498325933 arcseconds
#
# No Match - Norris non-member star index value: 102
# Distance: 0.12859178098392932 arcseconds
#
# No Match - Norris non-member star index value: 103
# Distance: 0.12323407155271993 arcseconds
#
# No Match - Norris non-member star index value: 104
# Distance: 71.00032420620305 arcseconds
#
# No Match - Norris non-member star index value: 105
# Distance: 0.4225612526880453 arcseconds
#
# Number of Norris non-member distance matches: 0
# Number of Norris non-member distance non-matches 106

# %% [markdown]
# ### Eliminating common values between the three data sets

# %%
#Koposov to Norris

foundcountkopnor=0

for kop in range(len(koppmra_fromgaia_byrv_inrange)):
    for nor in range(len(norrispmra_member)):
        if norrispmra_member[nor]==koppmra_fromgaia_byrv_inrange[kop]:
            foundcountkopnor+=1
print(foundcountkopnor)
# Out:
# 0

# %%
#Norris to Martin

foundcountnormar=1 #Sentinel value
while foundcountnormar!=0:#Sentinel value

    foundcountnormar=0

    normarloc=[]

    for nor in range(len(norrispmra_member)):
        for mar in range(len(martinpmra_member)):
            if norrispmra_member[nor]==martinpmra_member[mar]:
                normarloc.append(nor)
                foundcountnormar+=1


    print(foundcountnormar)
    print(normarloc)

    for i in range(len(normarloc)):
        del norrisrafit_member[normarloc[i]]
        del norrisdecfit_member[normarloc[i]]
        del norrispmra_member[normarloc[i]]
        del norrispmdec_member[normarloc[i]]
        del norrispmra_error_member[normarloc[i]]
        del norrispmdec_error_member[normarloc[i]]
# Out:
# 0
# []

# %%
#Koposov to Martin

foundcountkopmar=1 #Sentinel value

while foundcountkopmar!=0:
    
    foundcountkopmar=0
    
    kopmarloc=[]

    for kop in range(len(koppmra_fromgaia_byrv_inrange)):
        for mar in range(len(martinpmra_member)):
            if koppmra_fromgaia_byrv_inrange[kop]==martinpmra_member[mar]:
                kopmarloc.append(mar)
                foundcountkopmar+=1
    
    print(foundcountkopmar)
    print(kopmarloc)

    for j in range(len(kopmarloc)):
        del martinrafit_member[kopmarloc[j]]
        del martindecfit_member[kopmarloc[j]]
        del martinpmra_member[kopmarloc[j]]
        del martinpmdec_member[kopmarloc[j]]
        del martinpmra_error_member[kopmarloc[j]]
        del martinpmdec_error_member[kopmarloc[j]]
# Out:
# 4
# [5, 4, 3, 1]
# 0
# []

# %% [markdown]
# ### Plotting the proper motion without error bars

# %%
#Original gaia data in grey, koposov cross check is blue, martin cross check is red, Norris cross check is in green

plt.scatter(df.pmra,df.pmdec, s=4, color="grey")

plt.scatter(koppmra_fromgaia_byrv_inrange,koppmdec_fromgaia_byrv_inrange,color="blue",s=4) #The only proper motions with matching radial velocities

#plt.scatter(koppmra_fit_fromgaia_byrv_outrange,koppmdec_fit_fromgaia_byrv_outrange,color="orange",s=4) #The only proper motions with no matching radial velocities

plt.scatter(martinpmra_member,martinpmdec_member,s=4,color="red")

plt.scatter(norrispmra_member,norrispmdec_member,s=4,color="green")

plt.xlabel("μ$_α$ cosδ (mas yr$^{-1}$)")
plt.ylabel("μ$_δ$ (mas yr$^{-1}$)")
plt.title("Proper Motion of Boo I")
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.gca().set_aspect('equal', adjustable='box')
plt.savefig("ProperMotionScatterPlotNoError.png",dpi=300)

plt.show()

# %% [markdown]
# ### Plotting the proper motion with error bars

# %%
#This is with the radial velocities within 90-105 km/s range

pointsize=10

plt.scatter(df.pmra,df.pmdec,color="grey", s=pointsize)

graphboundary=5

plt.xlim(-graphboundary,graphboundary)
plt.ylim(-graphboundary,graphboundary)

#Koposov data
plt.scatter(koppmra_fromgaia_byrv_inrange,koppmdec_fromgaia_byrv_inrange,color="blue",s=pointsize) #The only proper motions with matching radial velocities
plt.errorbar(koppmra_fromgaia_byrv_inrange,koppmdec_fromgaia_byrv_inrange,koppmra_error_fromgaia_byrv_inrange,koppmdec_error_fromgaia_byrv_inrange,linestyle="none",capsize=3,color="blue",elinewidth=1)

#Martin Data
plt.scatter(martinpmra_member,martinpmdec_member,s=pointsize,color="red")
plt.errorbar(martinpmra_member,martinpmdec_member,martinpmra_error_member,martinpmdec_error_member,linestyle="none",capsize=3,color="red",elinewidth=1)

#Norris Data
plt.scatter(norrispmra_member,norrispmdec_member,s=pointsize,color="green")
plt.errorbar(norrispmra_member,norrispmdec_member,norrispmra_error_member,norrispmdec_error_member,linestyle="none",capsize=3,color="green",elinewidth=1)

plt.xlabel("μ$_α$ cos(δ) (mas yr$^{-1}$)")
plt.ylabel("μ$_δ$ (mas yr$^{-1}$)")
plt.title("Proper Motion of Boo I")
plt.gca().set_aspect('equal')
plt.savefig("ProperMotionScatterPlotWithError_byrv.png",dpi=300)

plt.show()

# %%
#This is just when using the minimum distance fitting algorithm

plt.scatter(df.pmra,df.pmdec,color="grey", s=20)

plt.xlim(-graphboundary,graphboundary)
plt.ylim(-graphboundary,graphboundary)

plt.errorbar(crosscheckpmra,crosscheckpmdec,crosscheckpmra_error,crosscheckpmdec_error,linestyle="none",capsize=3,color="blue",elinewidth=1)
plt.scatter(crosscheckpmra,crosscheckpmdec,color="blue",s=40)
plt.scatter(badpmra,badpmdec,color="red",marker="s",s=25)

plt.xlabel("μ$_α$ cos(δ) (mas yr$^{-1}$)")
plt.ylabel("μ$_δ$ (mas yr$^{-1}$)")
plt.title("Proper Motion of Boo I")
plt.gca().set_aspect('equal', adjustable='box')
plt.savefig("ProperMotionScatterPlotWithError_puredist.png",dpi=300)

plt.show()

# %% [markdown]
# ### Plotting the Color Magnitude Diagram without Error Bars

# %%
#plt.scatter((df.bp_rp), '''Placeholder for absolute magnitude''', s=1)
#plt.xlabel("B-R mean Magnitude")
#plt.ylabel("Absolute Magnitude")
#plt.title("Color magnitude diagram of Boo I")
#plt.savefig("ColorMagScatterPlot.png",dpi=300)
#plt.show()

# %% [markdown]
# ### Position Diagram

# %%
plt.scatter(df.ra,df.dec, s=25,color="grey",marker="+")

plt.scatter(kopra_nofit_byrv_inrange,kopdec_nofit_byrv_inrange,s=2,color="red")

plt.scatter(kopra_fit_byrv_inrange,kopdec_fit_byrv_inrange,s=2,color="blue")

plt.scatter(kopra_fit_byrv_outrange,kopdec_fit_byrv_outrange,s=2,color="green")

plt.scatter(kopra_nofit_byrv_outrange,kopdec_nofit_byrv_outrange,s=2,color="purple")

plt.xlabel("α")
plt.ylabel("δ")
plt.title("Position of Boo I")
plt.gca().set_aspect('equal')

plt.savefig("Positionplot.png",dpi=400)

plt.show()

print("Number of Koposov fits:",len(kopra_nofit_byrv_inrange)+len(kopra_fit_byrv_inrange)+len(kopra_fit_byrv_outrange)+len(kopra_nofit_byrv_outrange))
# Out:
# Number of Koposov fits: 112

# %%
for i in range(len(martinpmra_member)):
    if martinpmra_member[i]>0 and martinpmra_member[i]<2 and martinpmdec_member[i]<-2:
        print("RA:",martinrafit_member[i])
        print("Dec:",martindecfit_member[i])
        print("PM-RA:",martinpmra_member[i])
        print("PM-Dec:",martinpmdec_member[i])
        print()
#martinpmra_member,martinpmdec_member

# %%
for i in range(len(koppmdec_fromgaia_byrv_inrange)):
    if koppmdec_fromgaia_byrv_inrange[i]<=-5:
        print(i)
        print("Pm-Dec:",koppmdec_fromgaia_byrv_inrange[i])
        print("Pm-RA:",koppmra_fromgaia_byrv_inrange[i])
        print("RA:",kopra_fit_byrv_inrange[i])
        print("Dec:",kopdec_fit_byrv_inrange[i])

#checking for the index value of the outlier value
# Out:
# 23
# Pm-Dec: -11.386914993690866
# Pm-RA: -12.068816116220274
# RA: 210.0069
# Dec: 14.4152

# %%
#removing the outlier value

del koppmdec_fromgaia_byrv_inrange[15]
del koppmra_fromgaia_byrv_inrange[15]
del koppmdec_error_fromgaia_byrv_inrange[15]
del koppmra_error_fromgaia_byrv_inrange[15]
del kopra_fit_byrv_inrange[15]
del kopdec_fit_byrv_inrange[15]

# %%
for i in range(len(koppmdec_fromgaia_byrv_inrange)):
    if koppmdec_fromgaia_byrv_inrange[i]<=-5:
        print(i)
        print("Pm-Dec:",koppmdec_fromgaia_byrv_inrange[i])
        print("Pm-RA:",koppmra_fromgaia_byrv_inrange[i])
        print("RA:",kopra_fit_byrv_inrange[i])
        print("Dec:",kopdec_fit_byrv_inrange[i])
        
#Making sure the value was removed
# Out:
# 22
# Pm-Dec: -11.386914993690866
# Pm-RA: -12.068816116220274
# RA: 210.0069
# Dec: 14.4152

# %%
pmragraphlim=4

# %%
#pmra vs dec

plt.scatter(koppmra_fromgaia_byrv_inrange,kopdec_fit_byrv_inrange,color="blue",s=4)

plt.scatter(martinpmra_member,martindecfit_member,color="red",s=4)

plt.scatter(norrispmra_member,norrisdecfit_member,color="green",s=4)

plt.xlabel("μ$_α$ cos(δ) (mas yr$^{-1}$)")
plt.ylabel("Declination")
#plt.xlim(-pmragraphlim,pmragraphlim)
plt.savefig("PMRAvsDec.png",dpi=400)

# %%
#pmdec vs dec

plt.scatter(koppmdec_fromgaia_byrv_inrange,kopdec_fit_byrv_inrange,color="blue",s=4)

plt.scatter(martinpmdec_member,martindecfit_member,color="red",s=4)

plt.scatter(norrispmdec_member,norrisdecfit_member,color="green",s=4)

plt.xlabel("μ$_δ$ (mas yr$^{-1}$)")
plt.ylabel("Declination")

plt.savefig("PMDecvsDec.png",dpi=400)

# %%
#pmra vs ra

plt.scatter(koppmra_fromgaia_byrv_inrange,kopra_fit_byrv_inrange,color="blue",s=4)

plt.scatter(martinpmra_member,martinrafit_member,color="red",s=4)

plt.scatter(norrispmra_member,norrisrafit_member,color="green",s=4)

plt.xlabel("μ$_α$ cos(δ) (mas yr$^{-1}$)")
plt.ylabel("RA")

plt.savefig("PMRAvsRA.png",dpi=400)

# %%
#pmdec vs ra

plt.scatter(koppmdec_fromgaia_byrv_inrange,kopra_fit_byrv_inrange,color="blue",s=4)

plt.scatter(martinpmdec_member,martinrafit_member,color="red",s=4)

plt.scatter(norrispmdec_member,norrisrafit_member,color="green",s=4)

plt.xlabel("μ$_δ$ (mas yr$^{-1}$)")
plt.ylabel("RA")

plt.savefig("PMDecvsRA.png",dpi=400)

# %%
#Appending all the proper motions of koposov, martin, and norris

ra_all=[]
dec_all=[]
pmra_all=[]
pmdec_all=[]
pmra_error_all=[]
pmdec_error_all=[]

for i in range(len(koppmra_fromgaia_byrv_inrange)):
    ra_all.append(kopra_fit_byrv_inrange[i])
    dec_all.append(kopdec_fit_byrv_inrange[i])
    pmra_all.append(koppmra_fromgaia_byrv_inrange[i])
    pmdec_all.append(koppmdec_fromgaia_byrv_inrange[i])
    pmra_error_all.append(koppmra_error_fromgaia_byrv_inrange[i])
    pmdec_error_all.append(koppmdec_error_fromgaia_byrv_inrange[i])
    
for i in range(len(martinpmra_member)):
    ra_all.append(martinrafit_member[i])
    dec_all.append(martindecfit_member[i])
    pmra_all.append(martinpmra_member[i])
    pmdec_all.append(martinpmdec_member[i])
    pmra_error_all.append(martinpmra_error_member[i])
    pmdec_error_all.append(martinpmdec_error_member[i])

for i in range(len(norrispmra_member)):
    ra_all.append(norrisrafit_member[i])
    dec_all.append(norrisdecfit_member[i])
    pmra_all.append(norrispmra_member[i])
    pmdec_all.append(norrispmdec_member[i])
    pmra_error_all.append(norrispmra_error_member[i])
    pmdec_error_all.append(norrispmdec_error_member[i])

# %%
#pmra weighted means without sorting

pmrameantop=0
pmrameanbottom=0

for i in range(len(pmra_all)):
    pmrameantop+=pmra_all[i]/(pmra_error_all[i]**2)
    pmrameanbottom+=1/(pmra_error_all[i]**2)

pmra_mean_val=pmrameantop/pmrameanbottom
pmra_uncertainty=np.sqrt(1/(pmrameanbottom))

print("Mean PM-RA:",pmra_mean_val)
print("Uncertainty:",pmra_uncertainty)
# Out:
# Mean PM-RA: nan
# Uncertainty: nan

# %%
#pmdec weighted means

pmdecmeantop=0
pmdecmeanbottom=0

for i in range(len(pmdec_all)):
    pmdecmeantop+=pmdec_all[i]/(pmdec_error_all[i]**2)
    pmdecmeanbottom+=1/(pmdec_error_all[i]**2)
    
pmdec_mean_val=pmdecmeantop/pmdecmeanbottom
pmdec_uncertainty=np.sqrt(1/(pmdecmeanbottom))

print("Mean PM-Dec:",pmdec_mean_val)
print("Uncertainty:",pmdec_uncertainty)
# Out:
# Mean PM-Dec: nan
# Uncertainty: nan

# %%
plt.scatter(df.pmra,df.pmdec,color="grey", s=2)

plt.xlim(-graphboundary,graphboundary)
plt.ylim(-graphboundary,graphboundary)

plt.errorbar(pmra_mean_val,pmdec_mean_val,pmra_uncertainty,pmdec_uncertainty,color="black",capsize=3)

plt.xlabel("μ$_α$ cos(δ) (mas yr$^{-1}$)")
plt.ylabel("μ$_δ$ (mas yr$^{-1}$)")
plt.title("Proper Motion of Boo I")
plt.gca().set_aspect('equal', adjustable='box')
plt.savefig("ProperMotionWeightedMeanPlot.png",dpi=300)

plt.show()

# %% [markdown]
# ### Sorting by RA

# %%
import operator

#sorting algorithm here

radict_byra={}
decdict_byra={}
pmradict_byra={}
pmdecdict_byra={}
pmra_errordict_byra={}
pmdec_errordict_byra={}

a=len(ra_all)

for i in range(a): #appending all the ra values into a dictionary
    radict_byra[i]=ra_all[i]
    decdict_byra[i]=dec_all[i]
    pmradict_byra[i]=pmra_all[i]
    pmdecdict_byra[i]=pmdec_all[i]
    pmra_errordict_byra[i]=pmra_error_all[i]
    pmdec_errordict_byra[i]=pmdec_error_all[i]

sorted_radict = sorted(radict_byra.items(), key=operator.itemgetter(1))
radict_loc=[x[0] for x in sorted_radict]

ralistbyra=[]
declistbyra=[]
pmralistbyra=[]
pmdeclistbyra=[]
pmra_errorlistbyra=[]
pmdec_errorlistbyra=[]

for i in range(len(radict_loc)):
    ralistbyra.append(radict_byra[radict_loc[i]])
    declistbyra.append(decdict_byra[radict_loc[i]])
    pmralistbyra.append(pmradict_byra[radict_loc[i]])
    pmdeclistbyra.append(pmdecdict_byra[radict_loc[i]])
    pmra_errorlistbyra.append(pmra_errordict_byra[radict_loc[i]])
    pmdec_errorlistbyra.append(pmdec_errordict_byra[radict_loc[i]])

# %% [markdown]
# ### Top half and bottom half values after sorted by RA

# %%
#top half calculations

#Lists are categorized by coordinate system, which half, what it's sorted by, what side of the fraction

pmra_tophalf_byra_topfrac=0
pmra_tophalf_byra_bottomfrac=0

pmdec_tophalf_byra_topfrac=0
pmdec_tophalf_byra_bottomfrac=0

for i in range(int(len(ralistbyra)/2)):
    pmra_tophalf_byra_topfrac+=pmralistbyra[i]/(pmra_errorlistbyra[i])**2
    pmra_tophalf_byra_bottomfrac+=1/(pmra_errorlistbyra[i])**2 
    
    pmdec_tophalf_byra_topfrac+=pmdeclistbyra[i]/(pmdec_errorlistbyra[i])**2
    pmdec_tophalf_byra_bottomfrac+=1/(pmdec_errorlistbyra[i])**2
    
pmra_tophalf_byra_mean=pmra_tophalf_byra_topfrac/pmra_tophalf_byra_bottomfrac #pmra tophalf mean sorted by ra
pmra_error_tophalf_byra_mean=np.sqrt(1/pmra_tophalf_byra_bottomfrac) #pmra uncertainty tophalf mean sorted by ra

pmdec_tophalf_byra_mean=pmdec_tophalf_byra_topfrac/pmdec_tophalf_byra_bottomfrac #pmdec tophalf mean sorted by ra
pmdec_error_tophalf_byra_mean=np.sqrt(1/pmdec_tophalf_byra_bottomfrac) #pmdec uncertainty tophalf mean sorted by ra

# %%
#bottom half calculations

#Lists are categorized by coordinate system, which half, what it's sorted by

pmra_bottomhalf_byra_topfrac=0
pmra_bottomhalf_byra_bottomfrac=0

pmdec_bottomhalf_byra_topfrac=0
pmdec_bottomhalf_byra_bottomfrac=0

for i in range(int(len(ralistbyra)/2),int(len(ralistbyra))):
    pmra_bottomhalf_byra_topfrac+=pmralistbyra[i]/(pmra_errorlistbyra[i])**2
    pmra_bottomhalf_byra_bottomfrac+=1/(pmra_errorlistbyra[i])**2 

    pmdec_bottomhalf_byra_topfrac+=pmdeclistbyra[i]/(pmdec_errorlistbyra[i])**2
    pmdec_bottomhalf_byra_bottomfrac+=1/(pmdec_errorlistbyra[i])**2

pmra_bottomhalf_byra_mean=pmra_bottomhalf_byra_topfrac/pmra_bottomhalf_byra_bottomfrac #pmra bottom half mean sorted by ra
pmra_error_bottomhalf_byra_mean=np.sqrt(1/pmra_bottomhalf_byra_bottomfrac) #pmra uncertainty bottom half mean sorted by ra

pmdec_bottomhalf_byra_mean=pmdec_bottomhalf_byra_topfrac/pmdec_bottomhalf_byra_bottomfrac
pmdec_error_bottomhalf_byra_mean=np.sqrt(1/pmdec_bottomhalf_byra_bottomfrac)

# %%
#printing out the top half, bottom half pmra, pmdec, and uncertainties sorted by RA

print("Top Half PM-RA Mean after sorting by RA:",pmra_tophalf_byra_mean)
print("Top Half PM-RA Uncertainty Mean after sorting by RA:",pmra_error_tophalf_byra_mean)
print()
print("Bottom Half PM-RA Mean after sorting by RA:",pmra_bottomhalf_byra_mean)
print("Bottom Half PM-RA Uncertainty Mean after sorting by RA:",pmra_error_bottomhalf_byra_mean)
print()
print("Top Half PM-Dec Mean after sorting by RA:",pmdec_tophalf_byra_mean)
print("Top Half PM-Dec Uncertainty Mean after sorting by RA:",pmdec_error_tophalf_byra_mean)
print()
print("Bottom Half PM-Dec Mean after sorting by RA:",pmdec_bottomhalf_byra_mean)
print("Bottom Half PM-Dec Uncertainty Mean after sorting by RA:",pmdec_error_bottomhalf_byra_mean)
# Out:
# Top Half PM-RA Mean after sorting by RA: nan
# Top Half PM-RA Uncertainty Mean after sorting by RA: nan
#
# Bottom Half PM-RA Mean after sorting by RA: nan
# Bottom Half PM-RA Uncertainty Mean after sorting by RA: nan
#
# Top Half PM-Dec Mean after sorting by RA: nan
# Top Half PM-Dec Uncertainty Mean after sorting by RA: nan
#
# Bottom Half PM-Dec Mean after sorting by RA: nan
# Bottom Half PM-Dec Uncertainty Mean after sorting by RA: nan

# %% [markdown]
# ### Sorting by Dec

# %%
#sorting algorithm here

radict_bydec={}
decdict_bydec={}
pmradict_bydec={}
pmdecdict_bydec={}
pmra_errordict_bydec={}
pmdec_errordict_bydec={}

a=len(ra_all)

for i in range(a): #appending all the ra values into a dictionary
    radict_bydec[i]=ra_all[i]
    decdict_bydec[i]=dec_all[i]
    pmradict_bydec[i]=pmra_all[i]
    pmdecdict_bydec[i]=pmdec_all[i]
    pmra_errordict_bydec[i]=pmra_error_all[i]
    pmdec_errordict_bydec[i]=pmdec_error_all[i]

sorted_decdict = sorted(decdict_bydec.items(), key=operator.itemgetter(1))
decdict_loc=[x[0] for x in sorted_decdict]

ralistbydec=[]
declistbydec=[]
pmralistbydec=[]
pmdeclistbydec=[]
pmra_errorlistbydec=[]
pmdec_errorlistbydec=[]

for i in range(len(decdict_loc)):
    ralistbydec.append(radict_bydec[decdict_loc[i]])
    declistbydec.append(decdict_bydec[decdict_loc[i]])
    pmralistbydec.append(pmradict_bydec[decdict_loc[i]])
    pmdeclistbydec.append(pmdecdict_bydec[decdict_loc[i]])
    pmra_errorlistbydec.append(pmra_errordict_bydec[decdict_loc[i]])
    pmdec_errorlistbydec.append(pmdec_errordict_bydec[decdict_loc[i]])

# %% [markdown]
# ### Top half and bottom half values sorted by Dec

# %%
#top half calculations

pmra_tophalf_bydec_topfrac=0
pmra_tophalf_bydec_bottomfrac=0

pmdec_tophalf_bydec_topfrac=0
pmdec_tophalf_bydec_bottomfrac=0

for i in range(int(a/2)):
    pmra_tophalf_bydec_topfrac+=pmralistbydec[i]/(pmra_errorlistbydec[i]**2)
    pmra_tophalf_bydec_bottomfrac+=1/(pmra_errorlistbydec[i]**2)

    pmdec_tophalf_bydec_topfrac+=pmdeclistbydec[i]/(pmdec_errorlistbydec[i]**2)
    pmdec_tophalf_bydec_bottomfrac+=1/(pmdec_errorlistbydec[i]**2)

pmra_tophalf_bydec_mean=pmra_tophalf_bydec_topfrac/pmra_tophalf_bydec_bottomfrac
pmra_error_tophalf_bydec_mean=np.sqrt(1/pmra_tophalf_bydec_bottomfrac)

pmdec_tophalf_bydec_mean=pmdec_tophalf_bydec_topfrac/pmdec_tophalf_bydec_bottomfrac
pmdec_error_tophalf_bydec_mean=np.sqrt(1/pmdec_tophalf_bydec_bottomfrac)

# %%
#bottom half calculations

pmra_bottomhalf_bydec_topfrac=0
pmra_bottomhalf_bydec_bottomfrac=0

pmdec_bottomhalf_bydec_topfrac=0
pmdec_bottomhalf_bydec_bottomfrac=0

for i in range(int(a/2),a):
    pmra_bottomhalf_bydec_topfrac+=pmralistbydec[i]/(pmra_errorlistbydec[i]**2)
    pmra_bottomhalf_bydec_bottomfrac+=1/(pmra_errorlistbydec[i]**2)

    pmdec_bottomhalf_bydec_topfrac+=pmdeclistbydec[i]/(pmdec_errorlistbydec[i]**2)
    pmdec_bottomhalf_bydec_bottomfrac+=1/(pmdec_errorlistbydec[i]**2)
    
pmra_bottomhalf_bydec_mean=pmra_bottomhalf_bydec_topfrac/pmra_bottomhalf_bydec_bottomfrac
pmra_error_bottomhalf_bydec_mean=np.sqrt(1/pmra_bottomhalf_bydec_bottomfrac)

pmdec_bottomhalf_bydec_mean=pmdec_bottomhalf_bydec_topfrac/pmdec_bottomhalf_bydec_bottomfrac
pmdec_error_bottomhalf_bydec_mean=np.sqrt(1/pmdec_bottomhalf_bydec_bottomfrac)

# %% [markdown]
# ### Printing out the top half and bottom half means

# %%
print("Top Half PM-RA Mean after sorting by Dec:",pmra_tophalf_bydec_mean)
print("Top Half PM-RA Uncertainty Mean after sorting by Dec:",pmra_error_tophalf_bydec_mean)
print()
print("Bottom Half PM-RA Mean after sorting by Dec:",pmra_bottomhalf_bydec_mean)
print("Bottom Half PM-RA Uncertainty Mean after sorting by Dec:",pmra_error_bottomhalf_bydec_mean)
print()
print("Top Half PM-Dec Mean after sorting by Dec:",pmdec_tophalf_bydec_mean)
print("Top Half PM-Dec Uncertainty Mean after sorting by Dec:",pmdec_error_tophalf_bydec_mean)
print()
print("Bottom Half PM-Dec Mean after sorting by Dec:",pmdec_bottomhalf_bydec_mean)
print("Bottom Half PM-Dec Uncertainty Mean after sorting by Dec:",pmdec_error_bottomhalf_bydec_mean)
# Out:
# Top Half PM-RA Mean after sorting by Dec: nan
# Top Half PM-RA Uncertainty Mean after sorting by Dec: nan
#
# Bottom Half PM-RA Mean after sorting by Dec: nan
# Bottom Half PM-RA Uncertainty Mean after sorting by Dec: nan
#
# Top Half PM-Dec Mean after sorting by Dec: nan
# Top Half PM-Dec Uncertainty Mean after sorting by Dec: nan
#
# Bottom Half PM-Dec Mean after sorting by Dec: nan
# Bottom Half PM-Dec Uncertainty Mean after sorting by Dec: nan

# %% [markdown]
# ### The Proper motion plots for the member data sets

# %%
plt.scatter(pmra_all,pmdec_all, s=2, color="red")
plt.errorbar(pmra_all,pmdec_all,pmra_error_all,pmdec_error_all,color="red",capsize=2,linestyle="none",elinewidth=1)

plt.scatter(pmra_mean_val,pmdec_mean_val,color="black",s=5)
plt.errorbar(pmra_mean_val,pmdec_mean_val,pmra_uncertainty,pmdec_uncertainty,color="black",capsize=0.2)

#plt.xlim(-5,5)
#plt.ylim(-5,5)

plt.xlabel("μ$_α$ cos(δ) (mas yr$^{-1}$)")
plt.ylabel("μ$_δ$ (mas yr$^{-1}$)")
plt.title("Proper Motion of Boo I")
plt.gca().set_aspect('equal', adjustable='box')

plt.scatter(pmra_mean_val,pmdec_mean_val,color="black",s=5)
plt.errorbar(pmra_mean_val,pmdec_mean_val,pmra_uncertainty,pmdec_uncertainty,color="black",capsize=0.2)

plt.grid()

plt.savefig("MemberPMRAvsMemberPMDec.png",dpi=300)

plt.show()

# %% [markdown]
# ### Chi Squared tests

# %%
pmrachisquare=0
pmdecchisquare=0

for i in range(len(pmra_all)):
    pmrachisquare+=((pmra_all[i]-pmra_mean_val)/pmra_error_all[i])**2
    pmdecchisquare+=((pmdec_all[i]-pmdec_mean_val)/pmdec_error_all[i])**2

print("n-1 d.o.f.:",len(pmra_all)-1)
print("PM-RA Chi Square Value:",pmrachisquare)
print("PM-Dec Chi Square Value:",pmdecchisquare)
# Out:
# n-1 d.o.f.: 65
# PM-RA Chi Square Value: nan
# PM-Dec Chi Square Value: nan

# %%
for i in range(len(pmra_all)):
    if pmdec_all[i]<-3.5 and pmra_all[i]>0:
        print(i)
        print("RA:",ra_all[i])
        print("Dec:",dec_all[i])
# Out:
# 0
# RA: 209.91400000000002
# Dec: 14.444
# 2
# RA: 209.93099999999998
# Dec: 14.5773
# 26
# RA: 210.0215
# Dec: 14.5744
